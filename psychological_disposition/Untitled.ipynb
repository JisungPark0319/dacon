# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
train_data = pd.read_csv('./data/train.csv', index_col='index')
test_data = pd.read_csv('./data/test_x.csv', index_col='index')

# %%
from lightgbm import LGBMClassifier
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score

# %%
x_all_train = train_data.drop('voted', axis=1)
x_all_label = train_data['voted']

# %%
object_columns = x_all_train.dtypes[x_all_train.dtypes == 'object'].index.tolist()
object_columns
# Out:
# ['age_group', 'gender', 'race', 'religion']

# %%
from sklearn.preprocessing import LabelEncoder
label_en = LabelEncoder()
x_all_train['label_age'] = label_en.fit_transform(x_all_train['age_group'])
test_data['label_age'] = label_en.transform(test_data['age_group'])
x_all_train['label_gender'] = label_en.fit_transform(x_all_train['gender'])
test_data['label_gender'] = label_en.transform(test_data['gender'])
x_all_train['label_race'] = label_en.fit_transform(x_all_train['race'])
test_data['label_race'] = label_en.transform(test_data['race'])
x_all_train['label_religion'] = label_en.fit_transform(x_all_train['religion'])
test_data['label_religion'] = label_en.transform(test_data['religion'])

# %%
x_all_train = x_all_train.drop(object_columns, axis=1)
test_data = test_data.drop(object_columns, axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(x_all_train, x_all_label, test_size=0.3)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((31872, 76), (13660, 76), (31872,), (13660,))

# %%
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (24, 64), 
    'min_child_samples': (10, 200), 
    'min_child_weight':(1, 50),
    'subsample':(0.5, 1.0),
    'colsample_bytree': (0.5, 1.0),
    'max_bin':(10, 500),
    'reg_lambda':(0.001, 10),
    'reg_alpha': (0.01, 50) 
}

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample, 
                colsample_bytree,max_bin, reg_lambda, reg_alpha):
    params = {
        "n_estimators":500, "learning_rate":0.02,
        'max_depth': int(round(max_depth)), #  호출 시 실수형 값이 들어오므로 정수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0), 
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0)
    }
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 300)
    valid_proba = lgb_model.predict_proba(X_valid)[:, 1]
    roc_auc = roc_auc_score(y_valid, valid_proba)
    
    return roc_auc

# %%
# BayesianOptimization객체를 수행할 함수와 search할 parameter 범위를 설정하여 생성. 
lgbBO = BayesianOptimization(lgb_roc_eval,bayesian_params , random_state=0)
# 함수 반환값이 최대가 되는 입력값 유추를 위한 iteration 수행. 
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776366	training's binary_logloss: 0.564959	valid_1's auc: 0.766107	valid_1's binary_logloss: 0.569672
# [200]	training's auc: 0.792352	training's binary_logloss: 0.544224	valid_1's auc: 0.769018	valid_1's binary_logloss: 0.55871
# [300]	training's auc: 0.806635	training's binary_logloss: 0.532212	valid_1's auc: 0.769895	valid_1's binary_logloss: 0.557158
# [400]	training's auc: 0.819907	training's binary_logloss: 0.521609	valid_1's auc: 0.769825	valid_1's binary_logloss: 0.556792
# [500]	training's auc: 0.831652	training's binary_logloss: 0.511943	valid_1's auc: 0.769624	valid_1's binary_logloss: 0.556775
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831652	training's binary_logloss: 0.511943	valid_1's auc: 0.769624	valid_1's binary_logloss: 0.556775
# |  1        |  0.7696   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.781975	training's binary_logloss: 0.56144	valid_1's auc: 0.769247	valid_1's binary_logloss: 0.567522
# [200]	training's auc: 0.79612	training's binary_logloss: 0.540757	valid_1's auc: 0.771553	valid_1's binary_logloss: 0.556216
# [300]	training's auc: 0.809865	training's binary_logloss: 0.529009	valid_1's auc: 0.771847	valid_1's binary_logloss: 0.554983
# [400]	training's auc: 0.821857	training's binary_logloss: 0.519433	valid_1's auc: 0.771617	valid_1's binary_logloss: 0.555088
# [500]	training's auc: 0.833038	training's binary_logloss: 0.51034	valid_1's auc: 0.77145	valid_1's binary_logloss: 0.555058
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.833038	training's binary_logloss: 0.51034	valid_1's auc: 0.77145	valid_1's binary_logloss: 0.555058
# |  2        |  0.7714   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.793249	training's binary_logloss: 0.552829	valid_1's auc: 0.768099	valid_1's binary_logloss: 0.565239
# [200]	training's auc: 0.819089	training's binary_logloss: 0.5255	valid_1's auc: 0.770358	valid_1's binary_logloss: 0.556359
# [300]	training's auc: 0.842377	training's binary_logloss: 0.505743	valid_1's auc: 0.770099	valid_1's binary_logloss: 0.555812
# [400]	training's auc: 0.86197	training's binary_logloss: 0.488166	valid_1's auc: 0.769989	valid_1's binary_logloss: 0.555787
# [500]	training's auc: 0.879089	training's binary_logloss: 0.472265	valid_1's auc: 0.769013	valid_1's binary_logloss: 0.55649
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.879089	training's binary_logloss: 0.472265	valid_1's auc: 0.769013	valid_1's binary_logloss: 0.55649
# |  3        |  0.769    |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.772907	training's binary_logloss: 0.565811	valid_1's auc: 0.764861	valid_1's binary_logloss: 0.569182
# [200]	training's auc: 0.786202	training's binary_logloss: 0.548637	valid_1's auc: 0.767853	valid_1's binary_logloss: 0.559841
# [300]	training's auc: 0.798092	training's binary_logloss: 0.538677	valid_1's auc: 0.76866	valid_1's binary_logloss: 0.558426
# [400]	training's auc: 0.80848	training's binary_logloss: 0.530215	valid_1's auc: 0.768754	valid_1's binary_logloss: 0.557914
# [500]	training's auc: 0.817375	training's binary_logloss: 0.52285	valid_1's auc: 0.768668	valid_1's binary_logloss: 0.557697
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.817375	training's binary_logloss: 0.52285	valid_1's auc: 0.768668	valid_1's binary_logloss: 0.557697
# |  4        |  0.7687   |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770072	training's binary_logloss: 0.568727	valid_1's auc: 0.765138	valid_1's binary_logloss: 0.570652
# [200]	training's auc: 0.781076	training's binary_logloss: 0.552067	valid_1's auc: 0.767991	valid_1's binary_logloss: 0.560117
# [300]	training's auc: 0.791067	training's binary_logloss: 0.543432	valid_1's auc: 0.768762	valid_1's binary_logloss: 0.558477
# [400]	training's auc: 0.799431	training's binary_logloss: 0.536617	valid_1's auc: 0.768714	valid_1's binary_logloss: 0.558134
# [500]	training's auc: 0.807021	training's binary_logloss: 0.530471	valid_1's auc: 0.769055	valid_1's binary_logloss: 0.557734
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.807021	training's binary_logloss: 0.530471	valid_1's auc: 0.769055	valid_1's binary_logloss: 0.557734
# |  5        |  0.7691   |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777885	training's binary_logloss: 0.567722	valid_1's auc: 0.768292	valid_1's binary_logloss: 0.572129
# [200]	training's auc: 0.790237	training's binary_logloss: 0.54606	valid_1's auc: 0.770772	valid_1's binary_logloss: 0.557993
# [300]	training's auc: 0.801633	training's binary_logloss: 0.535192	valid_1's auc: 0.771193	valid_1's binary_logloss: 0.555444
# [400]	training's auc: 0.8119	training's binary_logloss: 0.526769	valid_1's auc: 0.771212	valid_1's binary_logloss: 0.555082
# [500]	training's auc: 0.821144	training's binary_logloss: 0.519314	valid_1's auc: 0.770851	valid_1's binary_logloss: 0.555146
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.821144	training's binary_logloss: 0.519314	valid_1's auc: 0.770851	valid_1's binary_logloss: 0.555146
# |  6        |  0.7709   |  0.5483   |  401.0    |  14.14    |  128.6    |  45.43    |  24.12    |  5.173    |  4.869    |  0.9357   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.775337	training's binary_logloss: 0.563239	valid_1's auc: 0.767654	valid_1's binary_logloss: 0.566742
# [200]	training's auc: 0.787776	training's binary_logloss: 0.546333	valid_1's auc: 0.770373	valid_1's binary_logloss: 0.557149
# [300]	training's auc: 0.799275	training's binary_logloss: 0.53673	valid_1's auc: 0.77114	valid_1's binary_logloss: 0.555787
# [400]	training's auc: 0.80947	training's binary_logloss: 0.528599	valid_1's auc: 0.771074	valid_1's binary_logloss: 0.555508
# [500]	training's auc: 0.818439	training's binary_logloss: 0.521176	valid_1's auc: 0.77113	valid_1's binary_logloss: 0.555339
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.818439	training's binary_logloss: 0.521176	valid_1's auc: 0.77113	valid_1's binary_logloss: 0.555339
# |  7        |  0.7711   |  0.8377   |  406.4    |  15.44    |  94.62    |  39.16    |  24.79    |  12.17    |  2.526    |  0.5663   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.806272	training's binary_logloss: 0.55286	valid_1's auc: 0.769474	valid_1's binary_logloss: 0.57111
# [200]	training's auc: 0.831414	training's binary_logloss: 0.518422	valid_1's auc: 0.771482	valid_1's binary_logloss: 0.557037
# [300]	training's auc: 0.851875	training's binary_logloss: 0.498311	valid_1's auc: 0.771005	valid_1's binary_logloss: 0.555083
# [400]	training's auc: 0.867837	training's binary_logloss: 0.483391	valid_1's auc: 0.770331	valid_1's binary_logloss: 0.555187
# [500]	training's auc: 0.881811	training's binary_logloss: 0.469975	valid_1's auc: 0.769846	valid_1's binary_logloss: 0.555633
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.881811	training's binary_logloss: 0.469975	valid_1's auc: 0.769846	valid_1's binary_logloss: 0.555633
# |  8        |  0.7698   |  0.5237   |  399.1    |  10.06    |  99.13    |  42.12    |  58.58    |  0.4063   |  4.455    |  0.5701   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.768004	training's binary_logloss: 0.570149	valid_1's auc: 0.76452	valid_1's binary_logloss: 0.571164
# [200]	training's auc: 0.777337	training's binary_logloss: 0.554927	valid_1's auc: 0.767237	valid_1's binary_logloss: 0.560858
# [300]	training's auc: 0.7851	training's binary_logloss: 0.54786	valid_1's auc: 0.768104	valid_1's binary_logloss: 0.559129
# [400]	training's auc: 0.791495	training's binary_logloss: 0.542464	valid_1's auc: 0.768132	valid_1's binary_logloss: 0.558676
# [500]	training's auc: 0.797024	training's binary_logloss: 0.537965	valid_1's auc: 0.768277	valid_1's binary_logloss: 0.558364
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.797024	training's binary_logloss: 0.537965	valid_1's auc: 0.768277	valid_1's binary_logloss: 0.558364
# |  9        |  0.7683   |  0.8665   |  398.4    |  7.722    |  120.6    |  46.51    |  31.65    |  37.68    |  8.219    |  0.7291   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.785515	training's binary_logloss: 0.560259	valid_1's auc: 0.769846	valid_1's binary_logloss: 0.567971
# [200]	training's auc: 0.801066	training's binary_logloss: 0.537262	valid_1's auc: 0.772346	valid_1's binary_logloss: 0.555776
# [300]	training's auc: 0.815851	training's binary_logloss: 0.52433	valid_1's auc: 0.772267	valid_1's binary_logloss: 0.554317
# [400]	training's auc: 0.829403	training's binary_logloss: 0.513417	valid_1's auc: 0.771816	valid_1's binary_logloss: 0.554403
# [500]	training's auc: 0.841707	training's binary_logloss: 0.503366	valid_1's auc: 0.771076	valid_1's binary_logloss: 0.554749
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.841707	training's binary_logloss: 0.503366	valid_1's auc: 0.771076	valid_1's binary_logloss: 0.554749
# |  10       |  0.7711   |  0.6189   |  392.9    |  10.66    |  120.4    |  28.53    |  28.79    |  1.402    |  1.86     |  0.9778   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776618	training's binary_logloss: 0.570469	valid_1's auc: 0.767552	valid_1's binary_logloss: 0.574504
# [200]	training's auc: 0.788987	training's binary_logloss: 0.548017	valid_1's auc: 0.770513	valid_1's binary_logloss: 0.559207
# [300]	training's auc: 0.800604	training's binary_logloss: 0.53658	valid_1's auc: 0.770966	valid_1's binary_logloss: 0.556083
# [400]	training's auc: 0.810882	training's binary_logloss: 0.527921	valid_1's auc: 0.771308	valid_1's binary_logloss: 0.555341
# [500]	training's auc: 0.820203	training's binary_logloss: 0.520363	valid_1's auc: 0.771061	valid_1's binary_logloss: 0.555397
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.820203	training's binary_logloss: 0.520363	valid_1's auc: 0.771061	valid_1's binary_logloss: 0.555397
# |  11       |  0.7711   |  0.5017   |  393.7    |  10.71    |  119.0    |  45.57    |  28.2     |  10.95    |  4.662    |  0.9552   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777841	training's binary_logloss: 0.560471	valid_1's auc: 0.767717	valid_1's binary_logloss: 0.565301
# [200]	training's auc: 0.793033	training's binary_logloss: 0.54229	valid_1's auc: 0.770666	valid_1's binary_logloss: 0.556493
# [300]	training's auc: 0.807115	training's binary_logloss: 0.53104	valid_1's auc: 0.770812	valid_1's binary_logloss: 0.555648
# [400]	training's auc: 0.818857	training's binary_logloss: 0.521709	valid_1's auc: 0.770546	valid_1's binary_logloss: 0.55576
# [500]	training's auc: 0.829489	training's binary_logloss: 0.513037	valid_1's auc: 0.770646	valid_1's binary_logloss: 0.55559
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829489	training's binary_logloss: 0.513037	valid_1's auc: 0.770646	valid_1's binary_logloss: 0.55559
# |  12       |  0.7706   |  0.9563   |  375.1    |  10.2     |  81.58    |  43.72    |  25.36    |  3.104    |  4.511    |  0.973    |
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.782336	training's binary_logloss: 0.558112	valid_1's auc: 0.767465	valid_1's binary_logloss: 0.565231
# [200]	training's auc: 0.799744	training's binary_logloss: 0.538007	valid_1's auc: 0.770258	valid_1's binary_logloss: 0.556631
# [300]	training's auc: 0.815648	training's binary_logloss: 0.52493	valid_1's auc: 0.77052	valid_1's binary_logloss: 0.55584
# [400]	training's auc: 0.829142	training's binary_logloss: 0.513873	valid_1's auc: 0.769835	valid_1's binary_logloss: 0.556223
# [500]	training's auc: 0.841238	training's binary_logloss: 0.503515	valid_1's auc: 0.769409	valid_1's binary_logloss: 0.556451
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.841238	training's binary_logloss: 0.503515	valid_1's auc: 0.769409	valid_1's binary_logloss: 0.556451
# |  13       |  0.7694   |  0.9782   |  405.2    |  9.964    |  120.1    |  45.49    |  30.91    |  4.665    |  2.582    |  0.5503   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.779395	training's binary_logloss: 0.561643	valid_1's auc: 0.768664	valid_1's binary_logloss: 0.56679
# [200]	training's auc: 0.793414	training's binary_logloss: 0.542416	valid_1's auc: 0.770657	valid_1's binary_logloss: 0.556544
# [300]	training's auc: 0.80674	training's binary_logloss: 0.531227	valid_1's auc: 0.771355	valid_1's binary_logloss: 0.555103
# [400]	training's auc: 0.818487	training's binary_logloss: 0.521825	valid_1's auc: 0.771119	valid_1's binary_logloss: 0.55496
# [500]	training's auc: 0.828988	training's binary_logloss: 0.51329	valid_1's auc: 0.771119	valid_1's binary_logloss: 0.554926
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.828988	training's binary_logloss: 0.51329	valid_1's auc: 0.771119	valid_1's binary_logloss: 0.554926
# |  14       |  0.7711   |  0.7651   |  409.4    |  15.91    |  89.85    |  28.86    |  27.29    |  7.456    |  2.153    |  0.5601   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.786229	training's binary_logloss: 0.555904	valid_1's auc: 0.768479	valid_1's binary_logloss: 0.564891
# [200]	training's auc: 0.804723	training's binary_logloss: 0.534095	valid_1's auc: 0.771243	valid_1's binary_logloss: 0.555727
# [300]	training's auc: 0.821592	training's binary_logloss: 0.519838	valid_1's auc: 0.770997	valid_1's binary_logloss: 0.555012
# [400]	training's auc: 0.835596	training's binary_logloss: 0.508162	valid_1's auc: 0.770885	valid_1's binary_logloss: 0.554955
# [500]	training's auc: 0.848619	training's binary_logloss: 0.497198	valid_1's auc: 0.77064	valid_1's binary_logloss: 0.555088
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.848619	training's binary_logloss: 0.497198	valid_1's auc: 0.77064	valid_1's binary_logloss: 0.555088
# |  15       |  0.7706   |  0.8743   |  410.4    |  8.478    |  90.75    |  25.55    |  32.58    |  2.277    |  2.62     |  0.9573   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.784376	training's binary_logloss: 0.559951	valid_1's auc: 0.768982	valid_1's binary_logloss: 0.567353
# [200]	training's auc: 0.803933	training's binary_logloss: 0.536166	valid_1's auc: 0.771136	valid_1's binary_logloss: 0.55643
# [300]	training's auc: 0.821356	training's binary_logloss: 0.521182	valid_1's auc: 0.771912	valid_1's binary_logloss: 0.554874
# [400]	training's auc: 0.837512	training's binary_logloss: 0.50782	valid_1's auc: 0.772006	valid_1's binary_logloss: 0.554698
# [500]	training's auc: 0.851774	training's binary_logloss: 0.495514	valid_1's auc: 0.771658	valid_1's binary_logloss: 0.55479
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.851774	training's binary_logloss: 0.495514	valid_1's auc: 0.771658	valid_1's binary_logloss: 0.55479
# |  16       |  0.7717   |  0.7405   |  120.1    |  12.18    |  53.76    |  42.68    |  47.66    |  10.66    |  1.986    |  0.8184   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.768768	training's binary_logloss: 0.575316	valid_1's auc: 0.764314	valid_1's binary_logloss: 0.577007
# [200]	training's auc: 0.77856	training's binary_logloss: 0.55526	valid_1's auc: 0.766947	valid_1's binary_logloss: 0.562191
# [300]	training's auc: 0.788993	training's binary_logloss: 0.545389	valid_1's auc: 0.768265	valid_1's binary_logloss: 0.558908
# [400]	training's auc: 0.797815	training's binary_logloss: 0.53815	valid_1's auc: 0.768678	valid_1's binary_logloss: 0.558047
# [500]	training's auc: 0.805863	training's binary_logloss: 0.531714	valid_1's auc: 0.768662	valid_1's binary_logloss: 0.557857
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805863	training's binary_logloss: 0.531714	valid_1's auc: 0.768662	valid_1's binary_logloss: 0.557857
# |  17       |  0.7687   |  0.5286   |  456.4    |  13.47    |  96.72    |  41.56    |  61.51    |  29.92    |  3.57     |  0.8466   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.785307	training's binary_logloss: 0.558179	valid_1's auc: 0.768611	valid_1's binary_logloss: 0.566218
# [200]	training's auc: 0.80824	training's binary_logloss: 0.533532	valid_1's auc: 0.770899	valid_1's binary_logloss: 0.55669
# [300]	training's auc: 0.827953	training's binary_logloss: 0.516806	valid_1's auc: 0.77111	valid_1's binary_logloss: 0.555563
# [400]	training's auc: 0.845414	training's binary_logloss: 0.501904	valid_1's auc: 0.770769	valid_1's binary_logloss: 0.555569
# [500]	training's auc: 0.860818	training's binary_logloss: 0.488174	valid_1's auc: 0.77084	valid_1's binary_logloss: 0.555565
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.860818	training's binary_logloss: 0.488174	valid_1's auc: 0.77084	valid_1's binary_logloss: 0.555565
# |  18       |  0.7708   |  0.8432   |  117.3    |  15.56    |  55.58    |  45.5     |  56.35    |  10.01    |  5.595    |  0.7129   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.76896	training's binary_logloss: 0.569461	valid_1's auc: 0.764129	valid_1's binary_logloss: 0.571125
# [200]	training's auc: 0.778507	training's binary_logloss: 0.554173	valid_1's auc: 0.766928	valid_1's binary_logloss: 0.561201
# [300]	training's auc: 0.786834	training's binary_logloss: 0.546623	valid_1's auc: 0.767776	valid_1's binary_logloss: 0.559524
# [400]	training's auc: 0.793581	training's binary_logloss: 0.541	valid_1's auc: 0.767995	valid_1's binary_logloss: 0.558972
# [500]	training's auc: 0.798509	training's binary_logloss: 0.536888	valid_1's auc: 0.768063	valid_1's binary_logloss: 0.558745
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.798509	training's binary_logloss: 0.536888	valid_1's auc: 0.768063	valid_1's binary_logloss: 0.558745
# |  19       |  0.7681   |  0.9644   |  330.1    |  10.67    |  22.2     |  30.45    |  42.41    |  41.12    |  7.102    |  0.755    |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.773932	training's binary_logloss: 0.564034	valid_1's auc: 0.76638	valid_1's binary_logloss: 0.5674
# [200]	training's auc: 0.785757	training's binary_logloss: 0.547912	valid_1's auc: 0.769495	valid_1's binary_logloss: 0.557972
# [300]	training's auc: 0.796699	training's binary_logloss: 0.538721	valid_1's auc: 0.770449	valid_1's binary_logloss: 0.556515
# [400]	training's auc: 0.806136	training's binary_logloss: 0.53112	valid_1's auc: 0.77068	valid_1's binary_logloss: 0.556016
# [500]	training's auc: 0.814696	training's binary_logloss: 0.524164	valid_1's auc: 0.771149	valid_1's binary_logloss: 0.555542
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.814696	training's binary_logloss: 0.524164	valid_1's auc: 0.771149	valid_1's binary_logloss: 0.555542
# |  20       |  0.7711   |  0.9148   |  405.8    |  13.62    |  99.41    |  41.91    |  25.2     |  14.89    |  5.058    |  0.7823   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.781896	training's binary_logloss: 0.560613	valid_1's auc: 0.769004	valid_1's binary_logloss: 0.566857
# [200]	training's auc: 0.79729	training's binary_logloss: 0.539812	valid_1's auc: 0.771256	valid_1's binary_logloss: 0.556122
# [300]	training's auc: 0.811812	training's binary_logloss: 0.527452	valid_1's auc: 0.771524	valid_1's binary_logloss: 0.554958
# [400]	training's auc: 0.824103	training's binary_logloss: 0.5173	valid_1's auc: 0.770988	valid_1's binary_logloss: 0.555113
# [500]	training's auc: 0.835443	training's binary_logloss: 0.508086	valid_1's auc: 0.770791	valid_1's binary_logloss: 0.555226
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835443	training's binary_logloss: 0.508086	valid_1's auc: 0.770791	valid_1's binary_logloss: 0.555226
# |  21       |  0.7708   |  0.7372   |  395.1    |  9.926    |  117.4    |  21.88    |  29.82    |  6.39     |  3.154    |  0.6558   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776599	training's binary_logloss: 0.569956	valid_1's auc: 0.767373	valid_1's binary_logloss: 0.574151
# [200]	training's auc: 0.788802	training's binary_logloss: 0.547785	valid_1's auc: 0.770722	valid_1's binary_logloss: 0.55874
# [300]	training's auc: 0.800314	training's binary_logloss: 0.536722	valid_1's auc: 0.771316	valid_1's binary_logloss: 0.555847
# [400]	training's auc: 0.810497	training's binary_logloss: 0.528191	valid_1's auc: 0.771844	valid_1's binary_logloss: 0.555013
# [500]	training's auc: 0.819755	training's binary_logloss: 0.520745	valid_1's auc: 0.771475	valid_1's binary_logloss: 0.555129
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.819755	training's binary_logloss: 0.520745	valid_1's auc: 0.771475	valid_1's binary_logloss: 0.555129
# |  22       |  0.7715   |  0.5105   |  398.7    |  13.24    |  130.1    |  45.02    |  26.75    |  10.36    |  4.276    |  0.9536   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.778734	training's binary_logloss: 0.56847	valid_1's auc: 0.768201	valid_1's binary_logloss: 0.573421
# [200]	training's auc: 0.791048	training's binary_logloss: 0.546007	valid_1's auc: 0.770895	valid_1's binary_logloss: 0.558506
# [300]	training's auc: 0.802968	training's binary_logloss: 0.534455	valid_1's auc: 0.771135	valid_1's binary_logloss: 0.555702
# [400]	training's auc: 0.813491	training's binary_logloss: 0.525665	valid_1's auc: 0.771262	valid_1's binary_logloss: 0.555143
# [500]	training's auc: 0.82315	training's binary_logloss: 0.517863	valid_1's auc: 0.771019	valid_1's binary_logloss: 0.555166
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82315	training's binary_logloss: 0.517863	valid_1's auc: 0.771019	valid_1's binary_logloss: 0.555166
# |  23       |  0.771    |  0.5043   |  393.7    |  11.06    |  107.9    |  37.35    |  26.14    |  7.473    |  1.503    |  0.8145   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.774382	training's binary_logloss: 0.569132	valid_1's auc: 0.766951	valid_1's binary_logloss: 0.572435
# [200]	training's auc: 0.785926	training's binary_logloss: 0.549167	valid_1's auc: 0.769419	valid_1's binary_logloss: 0.559297
# [300]	training's auc: 0.79706	training's binary_logloss: 0.538779	valid_1's auc: 0.770811	valid_1's binary_logloss: 0.556252
# [400]	training's auc: 0.806755	training's binary_logloss: 0.530747	valid_1's auc: 0.771472	valid_1's binary_logloss: 0.555429
# [500]	training's auc: 0.815524	training's binary_logloss: 0.523557	valid_1's auc: 0.771489	valid_1's binary_logloss: 0.555325
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815524	training's binary_logloss: 0.523557	valid_1's auc: 0.771489	valid_1's binary_logloss: 0.555325
# |  24       |  0.7715   |  0.5741   |  116.0    |  9.64     |  49.82    |  34.27    |  33.3     |  18.11    |  5.631    |  0.9791   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.784953	training's binary_logloss: 0.562276	valid_1's auc: 0.769173	valid_1's binary_logloss: 0.569921
# [200]	training's auc: 0.802427	training's binary_logloss: 0.537611	valid_1's auc: 0.771529	valid_1's binary_logloss: 0.557034
# [300]	training's auc: 0.818942	training's binary_logloss: 0.523012	valid_1's auc: 0.772048	valid_1's binary_logloss: 0.554964
# [400]	training's auc: 0.833625	training's binary_logloss: 0.510699	valid_1's auc: 0.77182	valid_1's binary_logloss: 0.55475
# [500]	training's auc: 0.846545	training's binary_logloss: 0.499657	valid_1's auc: 0.771394	valid_1's binary_logloss: 0.554989
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.846545	training's binary_logloss: 0.499657	valid_1's auc: 0.771394	valid_1's binary_logloss: 0.554989
# |  25       |  0.7714   |  0.598    |  121.6    |  14.74    |  58.41    |  30.17    |  42.42    |  9.514    |  1.099    |  0.7963   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.780636	training's binary_logloss: 0.563032	valid_1's auc: 0.768904	valid_1's binary_logloss: 0.568569
# [200]	training's auc: 0.796228	training's binary_logloss: 0.541238	valid_1's auc: 0.771687	valid_1's binary_logloss: 0.556426
# [300]	training's auc: 0.810233	training's binary_logloss: 0.5291	valid_1's auc: 0.772058	valid_1's binary_logloss: 0.55498
# [400]	training's auc: 0.822814	training's binary_logloss: 0.518791	valid_1's auc: 0.771928	valid_1's binary_logloss: 0.554795
# [500]	training's auc: 0.83412	training's binary_logloss: 0.509191	valid_1's auc: 0.771697	valid_1's binary_logloss: 0.554894
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83412	training's binary_logloss: 0.509191	valid_1's auc: 0.771697	valid_1's binary_logloss: 0.554894
# |  26       |  0.7717   |  0.6805   |  122.8    |  10.41    |  64.17    |  45.41    |  36.49    |  10.44    |  4.067    |  0.7246   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.772923	training's binary_logloss: 0.567648	valid_1's auc: 0.767455	valid_1's binary_logloss: 0.569985
# [200]	training's auc: 0.782461	training's binary_logloss: 0.550261	valid_1's auc: 0.769999	valid_1's binary_logloss: 0.55799
# [300]	training's auc: 0.792317	training's binary_logloss: 0.541541	valid_1's auc: 0.771109	valid_1's binary_logloss: 0.555922
# [400]	training's auc: 0.801294	training's binary_logloss: 0.534352	valid_1's auc: 0.771095	valid_1's binary_logloss: 0.555664
# [500]	training's auc: 0.809239	training's binary_logloss: 0.527949	valid_1's auc: 0.770926	valid_1's binary_logloss: 0.555614
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.809239	training's binary_logloss: 0.527949	valid_1's auc: 0.770926	valid_1's binary_logloss: 0.555614
# |  27       |  0.7709   |  0.6718   |  130.8    |  6.468    |  46.64    |  44.35    |  33.8     |  17.11    |  0.1069   |  0.5059   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776921	training's binary_logloss: 0.563111	valid_1's auc: 0.768126	valid_1's binary_logloss: 0.567079
# [200]	training's auc: 0.790017	training's binary_logloss: 0.545191	valid_1's auc: 0.770638	valid_1's binary_logloss: 0.556933
# [300]	training's auc: 0.802075	training's binary_logloss: 0.534979	valid_1's auc: 0.771326	valid_1's binary_logloss: 0.555588
# [400]	training's auc: 0.812665	training's binary_logloss: 0.52639	valid_1's auc: 0.771547	valid_1's binary_logloss: 0.555254
# [500]	training's auc: 0.82206	training's binary_logloss: 0.518766	valid_1's auc: 0.771255	valid_1's binary_logloss: 0.555418
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82206	training's binary_logloss: 0.518766	valid_1's auc: 0.771255	valid_1's binary_logloss: 0.555418
# |  28       |  0.7713   |  0.7934   |  380.0    |  14.64    |  138.4    |  42.97    |  26.47    |  9.261    |  7.987    |  0.8535   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.779233	training's binary_logloss: 0.563356	valid_1's auc: 0.769095	valid_1's binary_logloss: 0.568128
# [200]	training's auc: 0.792288	training's binary_logloss: 0.543153	valid_1's auc: 0.772029	valid_1's binary_logloss: 0.556071
# [300]	training's auc: 0.804744	training's binary_logloss: 0.532411	valid_1's auc: 0.772009	valid_1's binary_logloss: 0.554762
# [400]	training's auc: 0.815963	training's binary_logloss: 0.523591	valid_1's auc: 0.771899	valid_1's binary_logloss: 0.554613
# [500]	training's auc: 0.826022	training's binary_logloss: 0.515508	valid_1's auc: 0.771465	valid_1's binary_logloss: 0.554813
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.826022	training's binary_logloss: 0.515508	valid_1's auc: 0.771465	valid_1's binary_logloss: 0.554813
# |  29       |  0.7715   |  0.6719   |  375.6    |  13.73    |  79.69    |  46.71    |  24.29    |  2.457    |  4.31     |  0.9288   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.791357	training's binary_logloss: 0.558501	valid_1's auc: 0.769348	valid_1's binary_logloss: 0.569087
# [200]	training's auc: 0.80983	training's binary_logloss: 0.532255	valid_1's auc: 0.771895	valid_1's binary_logloss: 0.556231
# [300]	training's auc: 0.827033	training's binary_logloss: 0.516599	valid_1's auc: 0.771994	valid_1's binary_logloss: 0.55443
# [400]	training's auc: 0.841777	training's binary_logloss: 0.503985	valid_1's auc: 0.771925	valid_1's binary_logloss: 0.554207
# [500]	training's auc: 0.85538	training's binary_logloss: 0.492318	valid_1's auc: 0.77112	valid_1's binary_logloss: 0.554578
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.85538	training's binary_logloss: 0.492318	valid_1's auc: 0.77112	valid_1's binary_logloss: 0.554578
# |  30       |  0.7711   |  0.5947   |  116.7    |  10.25    |  52.93    |  37.74    |  38.88    |  1.574    |  6.111    |  0.5157   |
# =====================================================================================================================================

# %%
lgbBO.res
# Out:
# [{'target': 0.7696239538289908,
#   'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.027633760716439,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917838234820016,
#    'subsample': 0.9818313802505146}},
#  {'target': 0.7714495726990379,
#   'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 11.288949197529044,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20316375600581688,
#    'subsample': 0.916309922773969}},
#  {'target': 0.7690128766113444,
#   'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.78618342232764,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.3995702922539115,
#    'subsample': 0.5716766437045232}},
#  {'target': 0.7686678358776573,
#   'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 10.146619399905235,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18887921456311507,
#    'subsample': 0.8088177485379385}},
#  {'target': 0.7690551362072843,
#   'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.437480785146242,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6031944908210691,
#    'subsample': 0.8333833577228338}},
#  {'target': 0.7708509527624875,
#   'params': {'colsample_bytree': 0.5483195764649221,
#    'max_bin': 401.03879182300506,
#    'max_depth': 14.138578179662963,
#    'min_child_samples': 128.62621503625422,
#    'min_child_weight': 45.42733955778281,
#    'num_leaves': 24.120198846552746,
#    'reg_alpha': 5.173294581452591,
#    'reg_lambda': 4.8690512202370355,
#    'subsample': 0.9356757030409497}},
#  {'target': 0.7711304197526283,
#   'params': {'colsample_bytree': 0.8376775379530563,
#    'max_bin': 406.4400963150039,
#    'max_depth': 15.436374024283813,
#    'min_child_samples': 94.61736804540286,
#    'min_child_weight': 39.16366316797149,
#    'num_leaves': 24.794635185600917,
#    'reg_alpha': 12.173502300398539,
#    'reg_lambda': 2.5259407573907864,
#    'subsample': 0.5663049255809645}},
#  {'target': 0.7698461303024249,
#   'params': {'colsample_bytree': 0.5236525048872487,
#    'max_bin': 399.1048829608746,
#    'max_depth': 10.058774818600948,
#    'min_child_samples': 99.13470367586314,
#    'min_child_weight': 42.11648311041011,
#    'num_leaves': 58.579455824404015,
#    'reg_alpha': 0.4062814658078957,
#    'reg_lambda': 4.454728183440481,
#    'subsample': 0.5701138033913072}},
#  {'target': 0.7682770535649461,
#   'params': {'colsample_bytree': 0.8664505763557047,
#    'max_bin': 398.409968123852,
#    'max_depth': 7.7217834594044055,
#    'min_child_samples': 120.56996969886812,
#    'min_child_weight': 46.51430327425089,
#    'num_leaves': 31.653562657817062,
#    'reg_alpha': 37.677147976621704,
#    'reg_lambda': 8.219359596778029,
#    'subsample': 0.7290788030213641}},
#  {'target': 0.7710755082305754,
#   'params': {'colsample_bytree': 0.6189462703770541,
#    'max_bin': 392.94877278898457,
#    'max_depth': 10.658120906310835,
#    'min_child_samples': 120.43360087481082,
#    'min_child_weight': 28.532714224576566,
#    'num_leaves': 28.788492710108248,
#    'reg_alpha': 1.4022242842850074,
#    'reg_lambda': 1.8604310194043097,
#    'subsample': 0.9778108224991804}},
#  {'target': 0.7710606503276016,
#   'params': {'colsample_bytree': 0.5017469237656516,
#    'max_bin': 393.72190024490175,
#    'max_depth': 10.707724066578827,
#    'min_child_samples': 118.96813016814396,
#    'min_child_weight': 45.56868876896979,
#    'num_leaves': 28.201502549830405,
#    'reg_alpha': 10.952704243299513,
#    'reg_lambda': 4.662235191571802,
#    'subsample': 0.9551699402948195}},
#  {'target': 0.7706463592222668,
#   'params': {'colsample_bytree': 0.9563147836294066,
#    'max_bin': 375.1326437527328,
#    'max_depth': 10.200412251868377,
#    'min_child_samples': 81.58287254145286,
#    'min_child_weight': 43.71975178208854,
#    'num_leaves': 25.355350542067324,
#    'reg_alpha': 3.103814808872753,
#    'reg_lambda': 4.510686993124545,
#    'subsample': 0.9730103376240282}},
#  {'target': 0.7694088710850695,
#   'params': {'colsample_bytree': 0.9782167671639709,
#    'max_bin': 405.17622665082996,
#    'max_depth': 9.963999389825155,
#    'min_child_samples': 120.05515868662658,
#    'min_child_weight': 45.4889809496013,
#    'num_leaves': 30.908237504024953,
#    'reg_alpha': 4.664506801110137,
#    'reg_lambda': 2.5815383931729894,
#    'subsample': 0.5502790294491018}},
#  {'target': 0.7711186545427045,
#   'params': {'colsample_bytree': 0.7651221306555884,
#    'max_bin': 409.43549264388423,
#    'max_depth': 15.913568644949489,
#    'min_child_samples': 89.84745150916926,
#    'min_child_weight': 28.861868047130866,
#    'num_leaves': 27.294867011003006,
#    'reg_alpha': 7.456288435976601,
#    'reg_lambda': 2.1528923070206587,
#    'subsample': 0.5601137251856271}},
#  {'target': 0.7706398278005812,
#   'params': {'colsample_bytree': 0.8742714717370526,
#    'max_bin': 410.4236625749573,
#    'max_depth': 8.478418898566606,
#    'min_child_samples': 90.7453738032045,
#    'min_child_weight': 25.551994580579326,
#    'num_leaves': 32.58286269297403,
#    'reg_alpha': 2.2769541159341227,
#    'reg_lambda': 2.619629859559997,
#    'subsample': 0.9572821132166465}},
#  {'target': 0.7716575833406705,
#   'params': {'colsample_bytree': 0.7405498719224073,
#    'max_bin': 120.09126734365545,
#    'max_depth': 12.17715628919504,
#    'min_child_samples': 53.75607426089902,
#    'min_child_weight': 42.67674438905004,
#    'num_leaves': 47.65645884299404,
#    'reg_alpha': 10.657030784872696,
#    'reg_lambda': 1.9862443324975898,
#    'subsample': 0.8183674135844643}},
#  {'target': 0.7686622344266091,
#   'params': {'colsample_bytree': 0.5285839690801153,
#    'max_bin': 456.3688492632358,
#    'max_depth': 13.466954424472686,
#    'min_child_samples': 96.71934046157652,
#    'min_child_weight': 41.56458449914903,
#    'num_leaves': 61.51356737319794,
#    'reg_alpha': 29.916479237807728,
#    'reg_lambda': 3.569830892060643,
#    'subsample': 0.8466234848633365}},
#  {'target': 0.7708400742687528,
#   'params': {'colsample_bytree': 0.8431874671322029,
#    'max_bin': 117.27609840715374,
#    'max_depth': 15.563015473146358,
#    'min_child_samples': 55.58490444988596,
#    'min_child_weight': 45.5001451110029,
#    'num_leaves': 56.35068484578852,
#    'reg_alpha': 10.007774170021364,
#    'reg_lambda': 5.594776817962894,
#    'subsample': 0.7129171851183944}},
#  {'target': 0.7680634630994896,
#   'params': {'colsample_bytree': 0.9644030062523238,
#    'max_bin': 330.0928781095815,
#    'max_depth': 10.672045120791337,
#    'min_child_samples': 22.200684457930734,
#    'min_child_weight': 30.449321845606374,
#    'num_leaves': 42.41391927150943,
#    'reg_alpha': 41.1241425119106,
#    'reg_lambda': 7.101780863951866,
#    'subsample': 0.7549971229139905}},
#  {'target': 0.7711487812659101,
#   'params': {'colsample_bytree': 0.9147931444632513,
#    'max_bin': 405.8020777563281,
#    'max_depth': 13.62127899409433,
#    'min_child_samples': 99.40729879657287,
#    'min_child_weight': 41.91291007373896,
#    'num_leaves': 25.203602518564324,
#    'reg_alpha': 14.889630041241624,
#    'reg_lambda': 5.058418619054611,
#    'subsample': 0.7822736325781997}},
#  {'target': 0.7707910453516619,
#   'params': {'colsample_bytree': 0.7372288280133774,
#    'max_bin': 395.08523164687153,
#    'max_depth': 9.92593642077257,
#    'min_child_samples': 117.42100040155707,
#    'min_child_weight': 21.882249832860197,
#    'num_leaves': 29.818985239229356,
#    'reg_alpha': 6.3897477042818025,
#    'reg_lambda': 3.1544862878802435,
#    'subsample': 0.6558474831369123}},
#  {'target': 0.7714753307229706,
#   'params': {'colsample_bytree': 0.5104787326342917,
#    'max_bin': 398.69892082989884,
#    'max_depth': 13.236462354331595,
#    'min_child_samples': 130.08977242029155,
#    'min_child_weight': 45.018126355157776,
#    'num_leaves': 26.752976319417883,
#    'reg_alpha': 10.362413846149888,
#    'reg_lambda': 4.275510833610375,
#    'subsample': 0.9535978292474994}},
#  {'target': 0.7710193207022991,
#   'params': {'colsample_bytree': 0.504294940162717,
#    'max_bin': 393.7324388712285,
#    'max_depth': 11.064488745005278,
#    'min_child_samples': 107.9297626784594,
#    'min_child_weight': 37.34645419074016,
#    'num_leaves': 26.138780649099093,
#    'reg_alpha': 7.472690661907608,
#    'reg_lambda': 1.5028963476919213,
#    'subsample': 0.8144534786446114}},
#  {'target': 0.7714889126197211,
#   'params': {'colsample_bytree': 0.5741090362257458,
#    'max_bin': 116.00812086814055,
#    'max_depth': 9.640119235248296,
#    'min_child_samples': 49.816436782850154,
#    'min_child_weight': 34.27317479355182,
#    'num_leaves': 33.304860293667126,
#    'reg_alpha': 18.105512149299003,
#    'reg_lambda': 5.63075525985665,
#    'subsample': 0.9790841667393939}},
#  {'target': 0.7713936663246754,
#   'params': {'colsample_bytree': 0.5980454481100592,
#    'max_bin': 121.64075129289058,
#    'max_depth': 14.736588811431243,
#    'min_child_samples': 58.41002770576262,
#    'min_child_weight': 30.173779030381453,
#    'num_leaves': 42.41965972656368,
#    'reg_alpha': 9.513539537572115,
#    'reg_lambda': 1.0991371446419091,
#    'subsample': 0.7962820861856135}},
#  {'target': 0.7716974855691806,
#   'params': {'colsample_bytree': 0.6804779156966985,
#    'max_bin': 122.77168512229849,
#    'max_depth': 10.405212126477284,
#    'min_child_samples': 64.16774634598869,
#    'min_child_weight': 45.408478873230514,
#    'num_leaves': 36.49221033431453,
#    'reg_alpha': 10.443766488322906,
#    'reg_lambda': 4.0672572786588175,
#    'subsample': 0.7245648436147007}},
#  {'target': 0.7709261722479936,
#   'params': {'colsample_bytree': 0.6718472100415225,
#    'max_bin': 130.82953330567452,
#    'max_depth': 6.468217174320246,
#    'min_child_samples': 46.638951338900945,
#    'min_child_weight': 44.34974881599864,
#    'num_leaves': 33.80334971507137,
#    'reg_alpha': 17.113597749945164,
#    'reg_lambda': 0.10686394565728931,
#    'subsample': 0.5059053335410414}},
#  {'target': 0.7712546681552253,
#   'params': {'colsample_bytree': 0.7934483034640649,
#    'max_bin': 380.0439532260079,
#    'max_depth': 14.643838974276168,
#    'min_child_samples': 138.43458222977384,
#    'min_child_weight': 42.970470635501016,
#    'num_leaves': 26.470019103325846,
#    'reg_alpha': 9.26093156336891,
#    'reg_lambda': 7.986961828262117,
#    'subsample': 0.8535084379864601}},
#  {'target': 0.7714653173182008,
#   'params': {'colsample_bytree': 0.6719031216057612,
#    'max_bin': 375.6081572776657,
#    'max_depth': 13.730267384261026,
#    'min_child_samples': 79.6866425505562,
#    'min_child_weight': 46.70901109047796,
#    'num_leaves': 24.292352746622498,
#    'reg_alpha': 2.457192349949748,
#    'reg_lambda': 4.31042600183802,
#    'subsample': 0.9287615530562456}},
#  {'target': 0.7711200603122723,
#   'params': {'colsample_bytree': 0.5946989585954869,
#    'max_bin': 116.72819845028508,
#    'max_depth': 10.245379076127314,
#    'min_child_samples': 52.93497052713143,
#    'min_child_weight': 37.74154630124517,
#    'num_leaves': 38.883930444962935,
#    'reg_alpha': 1.5744137125181323,
#    'reg_lambda': 6.111015680176461,
#    'subsample': 0.5156931099873915}}]

# %%
lgb_model = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 11,
                num_leaves=27,
                colsample_bytree=0.736,
                subsample=0.9163,
                max_bin=398,
                reg_alpha=4.366,
                reg_lambda=0.203,
                min_child_weight=46,
                min_child_samples=118,
                silent=-1,
                verbose=-1,
                )

# %%
lgb_model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_valid, y_valid)],
             eval_metric='auc', verbose=100, early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] num_threads is set with n_jobs=-1, nthread=4 will be ignored. Current value: num_threads=-1
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.78156	training's binary_logloss: 0.560793	valid_1's auc: 0.769183	valid_1's binary_logloss: 0.56665
# [200]	training's auc: 0.796438	training's binary_logloss: 0.540606	valid_1's auc: 0.771464	valid_1's binary_logloss: 0.556123
# [300]	training's auc: 0.810189	training's binary_logloss: 0.528951	valid_1's auc: 0.771639	valid_1's binary_logloss: 0.555112
# [400]	training's auc: 0.822178	training's binary_logloss: 0.519224	valid_1's auc: 0.771176	valid_1's binary_logloss: 0.555318
# Early stopping, best iteration is:
# [305]	training's auc: 0.810837	training's binary_logloss: 0.528434	valid_1's auc: 0.771684	valid_1's binary_logloss: 0.555074
# LGBMClassifier(colsample_bytree=0.736, learning_rate=0.02, max_bin=398,
#                max_depth=11, min_child_samples=118, min_child_weight=46,
#                n_estimators=1000, nthread=4, num_leaves=27, reg_alpha=4.366,
#                reg_lambda=0.203, silent=-1, subsample=0.9163, verbose=-1)

# %%
Q_E = ['QaE','QbE','QcE','QdE','QeE','QfE','QgE','QhE','QiE','QjE',
       'QkE','QlE','QmE','QnE','QoE','QpE','QqE','QrE','QsE','QtE']

# %%
x_all_train = train_data

# %%
for column in Q_E:
    x_all_train = x_all_train[x_all_train[column] < 15000]

# %%
for column in Q_E:
    x_all_train[column+'_log'] = np.log(x_all_train[column] + 1)

# %%
x_all_train = x_all_train.drop(Q_E, axis=1)

# %%
x_all_train.shape
# Out:
# (42512, 77)

# %%
x_all_train = train_data.drop('voted', axis=1)
x_all_label = train_data['voted']

# %%
label_en = LabelEncoder()
x_all_train['label_age'] = label_en.fit_transform(x_all_train['age_group'])
x_all_train['label_gender'] = label_en.fit_transform(x_all_train['gender'])
x_all_train['label_race'] = label_en.fit_transform(x_all_train['race'])
x_all_train['label_religion'] = label_en.fit_transform(x_all_train['religion'])

# %%
x_all_train = x_all_train.drop(object_columns, axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(x_all_train, x_all_label, test_size=0.43)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((25953, 76), (19579, 76), (25953,), (19579,))

# %%
# BayesianOptimization객체를 수행할 함수와 search할 parameter 범위를 설정하여 생성. 
lgbBO = BayesianOptimization(lgb_roc_eval,bayesian_params , random_state=0)
# 함수 반환값이 최대가 되는 입력값 유추를 위한 iteration 수행. 
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.776422	training's binary_logloss: 0.565631	valid_1's auc: 0.761709	valid_1's binary_logloss: 0.572074
# [200]	training's auc: 0.793349	training's binary_logloss: 0.544345	valid_1's auc: 0.764305	valid_1's binary_logloss: 0.5616
# [300]	training's auc: 0.809636	training's binary_logloss: 0.530743	valid_1's auc: 0.765473	valid_1's binary_logloss: 0.559816
# [400]	training's auc: 0.823597	training's binary_logloss: 0.519104	valid_1's auc: 0.765385	valid_1's binary_logloss: 0.559661
# [500]	training's auc: 0.836268	training's binary_logloss: 0.508458	valid_1's auc: 0.76532	valid_1's binary_logloss: 0.559677
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.836268	training's binary_logloss: 0.508458	valid_1's auc: 0.76532	valid_1's binary_logloss: 0.559677
# |  1        |  0.7653   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.785998	training's binary_logloss: 0.560069	valid_1's auc: 0.764653	valid_1's binary_logloss: 0.570122
# [200]	training's auc: 0.802241	training's binary_logloss: 0.537408	valid_1's auc: 0.766364	valid_1's binary_logloss: 0.559717
# [300]	training's auc: 0.817655	training's binary_logloss: 0.524009	valid_1's auc: 0.766726	valid_1's binary_logloss: 0.55842
# [400]	training's auc: 0.831645	training's binary_logloss: 0.512273	valid_1's auc: 0.766326	valid_1's binary_logloss: 0.558551
# [500]	training's auc: 0.843975	training's binary_logloss: 0.501813	valid_1's auc: 0.765378	valid_1's binary_logloss: 0.559193
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.843975	training's binary_logloss: 0.501813	valid_1's auc: 0.765378	valid_1's binary_logloss: 0.559193
# |  2        |  0.7654   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.796285	training's binary_logloss: 0.552089	valid_1's auc: 0.763147	valid_1's binary_logloss: 0.567983
# [200]	training's auc: 0.825258	training's binary_logloss: 0.521834	valid_1's auc: 0.76508	valid_1's binary_logloss: 0.559638
# [300]	training's auc: 0.850387	training's binary_logloss: 0.499356	valid_1's auc: 0.765547	valid_1's binary_logloss: 0.558779
# [400]	training's auc: 0.872251	training's binary_logloss: 0.479407	valid_1's auc: 0.764534	valid_1's binary_logloss: 0.559466
# [500]	training's auc: 0.890179	training's binary_logloss: 0.461384	valid_1's auc: 0.764027	valid_1's binary_logloss: 0.560038
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.890179	training's binary_logloss: 0.461384	valid_1's auc: 0.764027	valid_1's binary_logloss: 0.560038
# |  3        |  0.764    |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.773022	training's binary_logloss: 0.566348	valid_1's auc: 0.760135	valid_1's binary_logloss: 0.571879
# [200]	training's auc: 0.786272	training's binary_logloss: 0.548863	valid_1's auc: 0.762717	valid_1's binary_logloss: 0.562884
# [300]	training's auc: 0.798567	training's binary_logloss: 0.538536	valid_1's auc: 0.763841	valid_1's binary_logloss: 0.561291
# [400]	training's auc: 0.809089	training's binary_logloss: 0.529925	valid_1's auc: 0.764129	valid_1's binary_logloss: 0.560951
# [500]	training's auc: 0.818461	training's binary_logloss: 0.522209	valid_1's auc: 0.764038	valid_1's binary_logloss: 0.560951
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.818461	training's binary_logloss: 0.522209	valid_1's auc: 0.764038	valid_1's binary_logloss: 0.560951
# |  4        |  0.764    |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770435	training's binary_logloss: 0.56926	valid_1's auc: 0.759935	valid_1's binary_logloss: 0.573704
# [200]	training's auc: 0.780037	training's binary_logloss: 0.553077	valid_1's auc: 0.762417	valid_1's binary_logloss: 0.563674
# [300]	training's auc: 0.789695	training's binary_logloss: 0.544626	valid_1's auc: 0.763656	valid_1's binary_logloss: 0.561805
# [400]	training's auc: 0.798571	training's binary_logloss: 0.53757	valid_1's auc: 0.764135	valid_1's binary_logloss: 0.561208
# [500]	training's auc: 0.804626	training's binary_logloss: 0.532571	valid_1's auc: 0.76432	valid_1's binary_logloss: 0.561046
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.804626	training's binary_logloss: 0.532571	valid_1's auc: 0.76432	valid_1's binary_logloss: 0.561046
# |  5        |  0.7643   |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.775786	training's binary_logloss: 0.565174	valid_1's auc: 0.761989	valid_1's binary_logloss: 0.571187
# [200]	training's auc: 0.78842	training's binary_logloss: 0.547124	valid_1's auc: 0.764138	valid_1's binary_logloss: 0.561543
# [300]	training's auc: 0.800858	training's binary_logloss: 0.536595	valid_1's auc: 0.765303	valid_1's binary_logloss: 0.559863
# [400]	training's auc: 0.811642	training's binary_logloss: 0.527781	valid_1's auc: 0.765521	valid_1's binary_logloss: 0.55955
# [500]	training's auc: 0.82144	training's binary_logloss: 0.519638	valid_1's auc: 0.765553	valid_1's binary_logloss: 0.559451
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82144	training's binary_logloss: 0.519638	valid_1's auc: 0.765553	valid_1's binary_logloss: 0.559451
# |  6        |  0.7656   |  0.8042   |  383.9    |  7.774    |  101.4    |  38.99    |  29.6     |  18.73    |  6.178    |  0.5209   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.807522	training's binary_logloss: 0.55124	valid_1's auc: 0.765541	valid_1's binary_logloss: 0.572123
# [200]	training's auc: 0.82894	training's binary_logloss: 0.518978	valid_1's auc: 0.767307	valid_1's binary_logloss: 0.55901
# [300]	training's auc: 0.846456	training's binary_logloss: 0.500972	valid_1's auc: 0.76754	valid_1's binary_logloss: 0.556951
# [400]	training's auc: 0.86187	training's binary_logloss: 0.487006	valid_1's auc: 0.767014	valid_1's binary_logloss: 0.557
# [500]	training's auc: 0.875073	training's binary_logloss: 0.474712	valid_1's auc: 0.766273	valid_1's binary_logloss: 0.557555
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.875073	training's binary_logloss: 0.474712	valid_1's auc: 0.766273	valid_1's binary_logloss: 0.557555
# |  7        |  0.7663   |  0.5282   |  392.4    |  7.484    |  54.59    |  27.0     |  59.66    |  1.469    |  0.7769   |  0.8499   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.796737	training's binary_logloss: 0.554533	valid_1's auc: 0.765243	valid_1's binary_logloss: 0.569391
# [200]	training's auc: 0.817064	training's binary_logloss: 0.527019	valid_1's auc: 0.767291	valid_1's binary_logloss: 0.55852
# [300]	training's auc: 0.836248	training's binary_logloss: 0.509689	valid_1's auc: 0.767276	valid_1's binary_logloss: 0.557278
# [400]	training's auc: 0.853993	training's binary_logloss: 0.49472	valid_1's auc: 0.766754	valid_1's binary_logloss: 0.557474
# [500]	training's auc: 0.868578	training's binary_logloss: 0.481357	valid_1's auc: 0.766072	valid_1's binary_logloss: 0.557872
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.868578	training's binary_logloss: 0.481357	valid_1's auc: 0.766072	valid_1's binary_logloss: 0.557872
# |  8        |  0.7661   |  0.6344   |  430.9    |  10.56    |  10.4     |  20.87    |  33.8     |  0.8925   |  2.51     |  0.7914   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.76589	training's binary_logloss: 0.5726	valid_1's auc: 0.757442	valid_1's binary_logloss: 0.575774
# [200]	training's auc: 0.772143	training's binary_logloss: 0.559291	valid_1's auc: 0.760188	valid_1's binary_logloss: 0.566144
# [300]	training's auc: 0.777687	training's binary_logloss: 0.553572	valid_1's auc: 0.761636	valid_1's binary_logloss: 0.563961
# [400]	training's auc: 0.781728	training's binary_logloss: 0.550105	valid_1's auc: 0.762374	valid_1's binary_logloss: 0.563096
# [500]	training's auc: 0.784108	training's binary_logloss: 0.54795	valid_1's auc: 0.762778	valid_1's binary_logloss: 0.562699
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.784108	training's binary_logloss: 0.54795	valid_1's auc: 0.762778	valid_1's binary_logloss: 0.562699
# |  9        |  0.7628   |  0.9631   |  446.5    |  7.922    |  22.72    |  47.56    |  63.01    |  47.64    |  2.186    |  0.8902   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.795921	training's binary_logloss: 0.551025	valid_1's auc: 0.763054	valid_1's binary_logloss: 0.5672
# [200]	training's auc: 0.819352	training's binary_logloss: 0.52486	valid_1's auc: 0.765656	valid_1's binary_logloss: 0.559122
# [300]	training's auc: 0.840244	training's binary_logloss: 0.506297	valid_1's auc: 0.76614	valid_1's binary_logloss: 0.558291
# [400]	training's auc: 0.858074	training's binary_logloss: 0.490457	valid_1's auc: 0.765805	valid_1's binary_logloss: 0.558466
# [500]	training's auc: 0.87329	training's binary_logloss: 0.476279	valid_1's auc: 0.765009	valid_1's binary_logloss: 0.559157
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.87329	training's binary_logloss: 0.476279	valid_1's auc: 0.765009	valid_1's binary_logloss: 0.559157
# |  10       |  0.765    |  0.9776   |  391.0    |  7.941    |  24.05    |  8.176    |  39.89    |  2.652    |  6.944    |  0.7321   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.77766	training's binary_logloss: 0.570477	valid_1's auc: 0.762851	valid_1's binary_logloss: 0.57708
# [200]	training's auc: 0.791269	training's binary_logloss: 0.547038	valid_1's auc: 0.765264	valid_1's binary_logloss: 0.562619
# [300]	training's auc: 0.804501	training's binary_logloss: 0.5342	valid_1's auc: 0.766483	valid_1's binary_logloss: 0.55919
# [400]	training's auc: 0.816002	training's binary_logloss: 0.524358	valid_1's auc: 0.767091	valid_1's binary_logloss: 0.558208
# [500]	training's auc: 0.82634	training's binary_logloss: 0.515692	valid_1's auc: 0.766715	valid_1's binary_logloss: 0.558345
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82634	training's binary_logloss: 0.515692	valid_1's auc: 0.766715	valid_1's binary_logloss: 0.558345
# |  11       |  0.7667   |  0.5017   |  393.7    |  10.71    |  119.0    |  45.57    |  28.2     |  10.95    |  4.662    |  0.9552   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.798836	training's binary_logloss: 0.549797	valid_1's auc: 0.762885	valid_1's binary_logloss: 0.567558
# [200]	training's auc: 0.829097	training's binary_logloss: 0.518523	valid_1's auc: 0.765131	valid_1's binary_logloss: 0.559473
# [300]	training's auc: 0.855178	training's binary_logloss: 0.4954	valid_1's auc: 0.765409	valid_1's binary_logloss: 0.558943
# [400]	training's auc: 0.876499	training's binary_logloss: 0.475107	valid_1's auc: 0.7645	valid_1's binary_logloss: 0.559784
# [500]	training's auc: 0.895128	training's binary_logloss: 0.456315	valid_1's auc: 0.763608	valid_1's binary_logloss: 0.560708
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.895128	training's binary_logloss: 0.456315	valid_1's auc: 0.763608	valid_1's binary_logloss: 0.560708
# |  12       |  0.7636   |  0.9594   |  400.4    |  11.54    |  45.11    |  24.91    |  58.8     |  7.638    |  2.015    |  0.5684   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.802674	training's binary_logloss: 0.549009	valid_1's auc: 0.764139	valid_1's binary_logloss: 0.567967
# [200]	training's auc: 0.823029	training's binary_logloss: 0.52192	valid_1's auc: 0.765919	valid_1's binary_logloss: 0.559025
# [300]	training's auc: 0.84165	training's binary_logloss: 0.504978	valid_1's auc: 0.766227	valid_1's binary_logloss: 0.558034
# [400]	training's auc: 0.857345	training's binary_logloss: 0.491103	valid_1's auc: 0.765604	valid_1's binary_logloss: 0.55843
# [500]	training's auc: 0.87054	training's binary_logloss: 0.4789	valid_1's auc: 0.765166	valid_1's binary_logloss: 0.558882
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.87054	training's binary_logloss: 0.4789	valid_1's auc: 0.765166	valid_1's binary_logloss: 0.558882
# |  13       |  0.7652   |  0.7712   |  394.7    |  7.484    |  57.59    |  28.48    |  61.85    |  1.375    |  7.275    |  0.7356   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.774415	training's binary_logloss: 0.569257	valid_1's auc: 0.761891	valid_1's binary_logloss: 0.574663
# [200]	training's auc: 0.786956	training's binary_logloss: 0.548986	valid_1's auc: 0.764612	valid_1's binary_logloss: 0.562274
# [300]	training's auc: 0.799463	training's binary_logloss: 0.537847	valid_1's auc: 0.766236	valid_1's binary_logloss: 0.559637
# [400]	training's auc: 0.810161	training's binary_logloss: 0.529092	valid_1's auc: 0.766647	valid_1's binary_logloss: 0.558947
# [500]	training's auc: 0.819592	training's binary_logloss: 0.521244	valid_1's auc: 0.766553	valid_1's binary_logloss: 0.558924
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.819592	training's binary_logloss: 0.521244	valid_1's auc: 0.766553	valid_1's binary_logloss: 0.558924
# |  14       |  0.7666   |  0.6185   |  397.3    |  11.78    |  119.8    |  46.66    |  29.44    |  17.14    |  7.716    |  0.563    |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777969	training's binary_logloss: 0.562457	valid_1's auc: 0.761583	valid_1's binary_logloss: 0.56997
# [200]	training's auc: 0.791419	training's binary_logloss: 0.54455	valid_1's auc: 0.764524	valid_1's binary_logloss: 0.560839
# [300]	training's auc: 0.804716	training's binary_logloss: 0.533432	valid_1's auc: 0.76575	valid_1's binary_logloss: 0.559392
# [400]	training's auc: 0.816495	training's binary_logloss: 0.523847	valid_1's auc: 0.76575	valid_1's binary_logloss: 0.559214
# [500]	training's auc: 0.826577	training's binary_logloss: 0.515323	valid_1's auc: 0.765341	valid_1's binary_logloss: 0.559441
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.826577	training's binary_logloss: 0.515323	valid_1's auc: 0.765341	valid_1's binary_logloss: 0.559441
# |  15       |  0.7653   |  0.9147   |  386.5    |  9.145    |  111.1    |  49.14    |  25.02    |  10.08    |  7.33     |  0.9481   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777189	training's binary_logloss: 0.564369	valid_1's auc: 0.762133	valid_1's binary_logloss: 0.571126
# [200]	training's auc: 0.792045	training's binary_logloss: 0.544923	valid_1's auc: 0.764596	valid_1's binary_logloss: 0.561399
# [300]	training's auc: 0.806181	training's binary_logloss: 0.533059	valid_1's auc: 0.765713	valid_1's binary_logloss: 0.559741
# [400]	training's auc: 0.818371	training's binary_logloss: 0.522942	valid_1's auc: 0.765562	valid_1's binary_logloss: 0.559604
# [500]	training's auc: 0.829249	training's binary_logloss: 0.513753	valid_1's auc: 0.765498	valid_1's binary_logloss: 0.559569
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829249	training's binary_logloss: 0.513753	valid_1's auc: 0.765498	valid_1's binary_logloss: 0.559569
# |  16       |  0.7655   |  0.7953   |  381.3    |  8.996    |  103.8    |  43.68    |  33.49    |  16.56    |  4.683    |  0.623    |
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.783888	training's binary_logloss: 0.565569	valid_1's auc: 0.764189	valid_1's binary_logloss: 0.574582
# [200]	training's auc: 0.800594	training's binary_logloss: 0.540079	valid_1's auc: 0.766649	valid_1's binary_logloss: 0.560669
# [300]	training's auc: 0.815831	training's binary_logloss: 0.52569	valid_1's auc: 0.767145	valid_1's binary_logloss: 0.558189
# [400]	training's auc: 0.829314	training's binary_logloss: 0.514154	valid_1's auc: 0.767109	valid_1's binary_logloss: 0.55784
# [500]	training's auc: 0.841345	training's binary_logloss: 0.503942	valid_1's auc: 0.766477	valid_1's binary_logloss: 0.558283
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.841345	training's binary_logloss: 0.503942	valid_1's auc: 0.766477	valid_1's binary_logloss: 0.558283
# |  17       |  0.7665   |  0.5314   |  400.1    |  9.443    |  120.1    |  41.61    |  31.39    |  6.688    |  3.806    |  0.6668   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.78155	training's binary_logloss: 0.561509	valid_1's auc: 0.76292	valid_1's binary_logloss: 0.57004
# [200]	training's auc: 0.797062	training's binary_logloss: 0.540895	valid_1's auc: 0.765277	valid_1's binary_logloss: 0.560498
# [300]	training's auc: 0.812446	training's binary_logloss: 0.528063	valid_1's auc: 0.766235	valid_1's binary_logloss: 0.559033
# [400]	training's auc: 0.825575	training's binary_logloss: 0.517168	valid_1's auc: 0.765934	valid_1's binary_logloss: 0.559056
# [500]	training's auc: 0.836853	training's binary_logloss: 0.50753	valid_1's auc: 0.765841	valid_1's binary_logloss: 0.559123
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.836853	training's binary_logloss: 0.50753	valid_1's auc: 0.765841	valid_1's binary_logloss: 0.559123
# |  18       |  0.7658   |  0.7863   |  396.0    |  7.421    |  120.8    |  43.89    |  36.43    |  11.77    |  2.677    |  0.9393   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.787996	training's binary_logloss: 0.55755	valid_1's auc: 0.764153	valid_1's binary_logloss: 0.568623
# [200]	training's auc: 0.806161	training's binary_logloss: 0.534578	valid_1's auc: 0.766593	valid_1's binary_logloss: 0.559157
# [300]	training's auc: 0.822885	training's binary_logloss: 0.520039	valid_1's auc: 0.767033	valid_1's binary_logloss: 0.557965
# [400]	training's auc: 0.836936	training's binary_logloss: 0.507955	valid_1's auc: 0.76674	valid_1's binary_logloss: 0.55808
# [500]	training's auc: 0.850067	training's binary_logloss: 0.496458	valid_1's auc: 0.765912	valid_1's binary_logloss: 0.558648
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.850067	training's binary_logloss: 0.496458	valid_1's auc: 0.765912	valid_1's binary_logloss: 0.558648
# |  19       |  0.7659   |  0.7933   |  401.2    |  7.802    |  124.7    |  36.73    |  33.84    |  5.926    |  6.647    |  0.6768   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.771888	training's binary_logloss: 0.571339	valid_1's auc: 0.761465	valid_1's binary_logloss: 0.575612
# [200]	training's auc: 0.782251	training's binary_logloss: 0.552153	valid_1's auc: 0.76401	valid_1's binary_logloss: 0.56291
# [300]	training's auc: 0.793281	training's binary_logloss: 0.542051	valid_1's auc: 0.765547	valid_1's binary_logloss: 0.560079
# [400]	training's auc: 0.802862	training's binary_logloss: 0.534275	valid_1's auc: 0.766165	valid_1's binary_logloss: 0.559195
# [500]	training's auc: 0.811744	training's binary_logloss: 0.527058	valid_1's auc: 0.766284	valid_1's binary_logloss: 0.558952
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.811744	training's binary_logloss: 0.527058	valid_1's auc: 0.766284	valid_1's binary_logloss: 0.558952
# |  20       |  0.7663   |  0.5939   |  382.4    |  7.093    |  99.18    |  39.16    |  32.95    |  23.47    |  1.249    |  0.781    |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.782885	training's binary_logloss: 0.560658	valid_1's auc: 0.762873	valid_1's binary_logloss: 0.569904
# [200]	training's auc: 0.802404	training's binary_logloss: 0.538046	valid_1's auc: 0.765193	valid_1's binary_logloss: 0.560467
# [300]	training's auc: 0.819993	training's binary_logloss: 0.523286	valid_1's auc: 0.765997	valid_1's binary_logloss: 0.559154
# [400]	training's auc: 0.835108	training's binary_logloss: 0.510386	valid_1's auc: 0.765613	valid_1's binary_logloss: 0.559203
# [500]	training's auc: 0.848023	training's binary_logloss: 0.498953	valid_1's auc: 0.765483	valid_1's binary_logloss: 0.55931
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.848023	training's binary_logloss: 0.498953	valid_1's auc: 0.765483	valid_1's binary_logloss: 0.55931
# |  21       |  0.7655   |  0.8334   |  384.0    |  9.215    |  100.6    |  43.76    |  40.48    |  12.06    |  4.414    |  0.7273   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.787019	training's binary_logloss: 0.559318	valid_1's auc: 0.764995	valid_1's binary_logloss: 0.569508
# [200]	training's auc: 0.802888	training's binary_logloss: 0.536552	valid_1's auc: 0.766487	valid_1's binary_logloss: 0.559284
# [300]	training's auc: 0.81858	training's binary_logloss: 0.523007	valid_1's auc: 0.76673	valid_1's binary_logloss: 0.558074
# [400]	training's auc: 0.83234	training's binary_logloss: 0.511506	valid_1's auc: 0.76653	valid_1's binary_logloss: 0.558117
# [500]	training's auc: 0.844958	training's binary_logloss: 0.500545	valid_1's auc: 0.765888	valid_1's binary_logloss: 0.558574
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.844958	training's binary_logloss: 0.500545	valid_1's auc: 0.765888	valid_1's binary_logloss: 0.558574
# |  22       |  0.7659   |  0.7023   |  398.4    |  8.187    |  115.5    |  34.38    |  28.76    |  5.645    |  0.6736   |  0.9335   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.786873	training's binary_logloss: 0.560546	valid_1's auc: 0.764461	valid_1's binary_logloss: 0.570857
# [200]	training's auc: 0.804764	training's binary_logloss: 0.536136	valid_1's auc: 0.76637	valid_1's binary_logloss: 0.559571
# [300]	training's auc: 0.821331	training's binary_logloss: 0.521505	valid_1's auc: 0.766739	valid_1's binary_logloss: 0.55798
# [400]	training's auc: 0.836311	training's binary_logloss: 0.508966	valid_1's auc: 0.76644	valid_1's binary_logloss: 0.558075
# [500]	training's auc: 0.849239	training's binary_logloss: 0.497639	valid_1's auc: 0.765739	valid_1's binary_logloss: 0.558541
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.849239	training's binary_logloss: 0.497639	valid_1's auc: 0.765739	valid_1's binary_logloss: 0.558541
# |  23       |  0.7657   |  0.652    |  403.9    |  15.49    |  128.7    |  40.26    |  32.06    |  5.745    |  6.553    |  0.5736   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.788367	training's binary_logloss: 0.555788	valid_1's auc: 0.763053	valid_1's binary_logloss: 0.567955
# [200]	training's auc: 0.807566	training's binary_logloss: 0.533018	valid_1's auc: 0.765218	valid_1's binary_logloss: 0.559653
# [300]	training's auc: 0.825282	training's binary_logloss: 0.517838	valid_1's auc: 0.765746	valid_1's binary_logloss: 0.558668
# [400]	training's auc: 0.839863	training's binary_logloss: 0.505426	valid_1's auc: 0.765566	valid_1's binary_logloss: 0.558723
# [500]	training's auc: 0.853099	training's binary_logloss: 0.493792	valid_1's auc: 0.765023	valid_1's binary_logloss: 0.559207
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.853099	training's binary_logloss: 0.493792	valid_1's auc: 0.765023	valid_1's binary_logloss: 0.559207
# |  24       |  0.765    |  0.9294   |  398.4    |  6.872    |  127.8    |  36.76    |  40.03    |  5.843    |  6.692    |  0.9305   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.775462	training's binary_logloss: 0.563945	valid_1's auc: 0.76094	valid_1's binary_logloss: 0.570282
# [200]	training's auc: 0.787332	training's binary_logloss: 0.547427	valid_1's auc: 0.763812	valid_1's binary_logloss: 0.561391
# [300]	training's auc: 0.799171	training's binary_logloss: 0.53746	valid_1's auc: 0.765103	valid_1's binary_logloss: 0.559819
# [400]	training's auc: 0.809734	training's binary_logloss: 0.528954	valid_1's auc: 0.765378	valid_1's binary_logloss: 0.559517
# [500]	training's auc: 0.818886	training's binary_logloss: 0.521401	valid_1's auc: 0.765419	valid_1's binary_logloss: 0.559495
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.818886	training's binary_logloss: 0.521401	valid_1's auc: 0.765419	valid_1's binary_logloss: 0.559495
# |  25       |  0.7654   |  0.9736   |  390.6    |  8.767    |  129.8    |  38.79    |  24.82    |  16.7     |  5.131    |  0.7406   |
# [LightGBM] [Warning] Accuracy may be bad since you didn't set num_leaves and 2^max_depth > num_leaves
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777426	training's binary_logloss: 0.565794	valid_1's auc: 0.762826	valid_1's binary_logloss: 0.572253
# [200]	training's auc: 0.791373	training's binary_logloss: 0.545312	valid_1's auc: 0.764943	valid_1's binary_logloss: 0.561124
# [300]	training's auc: 0.805244	training's binary_logloss: 0.533552	valid_1's auc: 0.766339	valid_1's binary_logloss: 0.559151
# [400]	training's auc: 0.816698	training's binary_logloss: 0.523947	valid_1's auc: 0.766232	valid_1's binary_logloss: 0.559021
# [500]	training's auc: 0.827409	training's binary_logloss: 0.515014	valid_1's auc: 0.766155	valid_1's binary_logloss: 0.559015
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.827409	training's binary_logloss: 0.515014	valid_1's auc: 0.766155	valid_1's binary_logloss: 0.559015
# |  26       |  0.7662   |  0.6835   |  405.8    |  14.41    |  109.7    |  42.46    |  30.83    |  15.85    |  2.89     |  0.8946   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.77319	training's binary_logloss: 0.567151	valid_1's auc: 0.761074	valid_1's binary_logloss: 0.572254
# [200]	training's auc: 0.784533	training's binary_logloss: 0.549825	valid_1's auc: 0.763618	valid_1's binary_logloss: 0.562214
# [300]	training's auc: 0.795932	training's binary_logloss: 0.540103	valid_1's auc: 0.76525	valid_1's binary_logloss: 0.560174
# [400]	training's auc: 0.805989	training's binary_logloss: 0.531941	valid_1's auc: 0.765387	valid_1's binary_logloss: 0.559872
# [500]	training's auc: 0.815138	training's binary_logloss: 0.524596	valid_1's auc: 0.765232	valid_1's binary_logloss: 0.559895
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815138	training's binary_logloss: 0.524596	valid_1's auc: 0.765232	valid_1's binary_logloss: 0.559895
# |  27       |  0.7652   |  0.8183   |  385.5    |  7.49     |  98.02    |  34.69    |  34.7     |  24.55    |  8.021    |  0.7279   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770766	training's binary_logloss: 0.572374	valid_1's auc: 0.761074	valid_1's binary_logloss: 0.5763
# [200]	training's auc: 0.780554	training's binary_logloss: 0.553577	valid_1's auc: 0.763581	valid_1's binary_logloss: 0.56352
# [300]	training's auc: 0.790587	training's binary_logloss: 0.544297	valid_1's auc: 0.76498	valid_1's binary_logloss: 0.560813
# [400]	training's auc: 0.799659	training's binary_logloss: 0.536993	valid_1's auc: 0.76558	valid_1's binary_logloss: 0.559931
# [500]	training's auc: 0.807485	training's binary_logloss: 0.530658	valid_1's auc: 0.765703	valid_1's binary_logloss: 0.559749
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.807485	training's binary_logloss: 0.530658	valid_1's auc: 0.765703	valid_1's binary_logloss: 0.559749
# |  28       |  0.7657   |  0.5919   |  394.4    |  13.89    |  110.8    |  40.17    |  27.87    |  26.3     |  4.01     |  0.5445   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.774719	training's binary_logloss: 0.565896	valid_1's auc: 0.761361	valid_1's binary_logloss: 0.571663
# [200]	training's auc: 0.788106	training's binary_logloss: 0.547782	valid_1's auc: 0.764115	valid_1's binary_logloss: 0.561837
# [300]	training's auc: 0.800216	training's binary_logloss: 0.537339	valid_1's auc: 0.765521	valid_1's binary_logloss: 0.559936
# [400]	training's auc: 0.810993	training's binary_logloss: 0.528508	valid_1's auc: 0.765869	valid_1's binary_logloss: 0.559516
# [500]	training's auc: 0.820659	training's binary_logloss: 0.520452	valid_1's auc: 0.765894	valid_1's binary_logloss: 0.559472
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.820659	training's binary_logloss: 0.520452	valid_1's auc: 0.765894	valid_1's binary_logloss: 0.559472
# |  29       |  0.7659   |  0.841    |  391.1    |  11.27    |  106.3    |  40.04    |  31.62    |  21.81    |  7.743    |  0.5615   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.784867	training's binary_logloss: 0.562039	valid_1's auc: 0.763821	valid_1's binary_logloss: 0.571606
# [200]	training's auc: 0.802645	training's binary_logloss: 0.537876	valid_1's auc: 0.765995	valid_1's binary_logloss: 0.560161
# [300]	training's auc: 0.819268	training's binary_logloss: 0.523163	valid_1's auc: 0.767183	valid_1's binary_logloss: 0.557998
# [400]	training's auc: 0.834013	training's binary_logloss: 0.510783	valid_1's auc: 0.767015	valid_1's binary_logloss: 0.5579
# [500]	training's auc: 0.846692	training's binary_logloss: 0.499657	valid_1's auc: 0.766412	valid_1's binary_logloss: 0.558317
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.846692	training's binary_logloss: 0.499657	valid_1's auc: 0.766412	valid_1's binary_logloss: 0.558317
# |  30       |  0.7664   |  0.6275   |  397.9    |  11.02    |  115.0    |  40.8     |  33.51    |  8.782    |  3.205    |  0.7034   |
# =====================================================================================================================================

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_en = StandardScaler()

# %%
x_all_train = train_data

# %%
for column in Q_E:
    x_all_train = x_all_train[x_all_train[column] < 15000]

# %%
for column in Q_E:
    x_all_train[column] = np.log(x_all_train[column] + 1)

# %%
for column in Q_E:
    x_all_train[column+'_std'] = std_en.fit_transform(x_all_train[[column]])

# %%
x_all_train = x_all_train.drop(Q_E, axis=1)

# %%
x_all_train = train_data.drop('voted', axis=1)
x_all_label = train_data['voted']

# %%
label_en = LabelEncoder()
x_all_train['label_age'] = label_en.fit_transform(x_all_train['age_group'])
x_all_train['label_gender'] = label_en.fit_transform(x_all_train['gender'])
x_all_train['label_race'] = label_en.fit_transform(x_all_train['race'])
x_all_train['label_religion'] = label_en.fit_transform(x_all_train['religion'])

# %%
x_all_train = x_all_train.drop(object_columns, axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(x_all_train, x_all_label, test_size=0.43)
X_train.shape, X_valid.shape, y_train.shape, y_valid.shape
# Out:
# ((25953, 76), (19579, 76), (25953,), (19579,))

# %%
# BayesianOptimization객체를 수행할 함수와 search할 parameter 범위를 설정하여 생성. 
lgbBO = BayesianOptimization(lgb_roc_eval,bayesian_params , random_state=0)
# 함수 반환값이 최대가 되는 입력값 유추를 위한 iteration 수행. 
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.772738	training's binary_logloss: 0.56792	valid_1's auc: 0.765735	valid_1's binary_logloss: 0.571302
# [200]	training's auc: 0.791702	training's binary_logloss: 0.546426	valid_1's auc: 0.767872	valid_1's binary_logloss: 0.559912
# [300]	training's auc: 0.808354	training's binary_logloss: 0.532996	valid_1's auc: 0.768013	valid_1's binary_logloss: 0.558176
# [400]	training's auc: 0.822865	training's binary_logloss: 0.521203	valid_1's auc: 0.76768	valid_1's binary_logloss: 0.557894
# [500]	training's auc: 0.835661	training's binary_logloss: 0.510549	valid_1's auc: 0.767404	valid_1's binary_logloss: 0.55782
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835661	training's binary_logloss: 0.510549	valid_1's auc: 0.767404	valid_1's binary_logloss: 0.55782
# |  1        |  0.7674   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.783995	training's binary_logloss: 0.561522	valid_1's auc: 0.76794	valid_1's binary_logloss: 0.569208
# [200]	training's auc: 0.801692	training's binary_logloss: 0.539157	valid_1's auc: 0.77014	valid_1's binary_logloss: 0.557642
# [300]	training's auc: 0.817833	training's binary_logloss: 0.525639	valid_1's auc: 0.77003	valid_1's binary_logloss: 0.55616
# [400]	training's auc: 0.832128	training's binary_logloss: 0.514016	valid_1's auc: 0.768971	valid_1's binary_logloss: 0.556484
# [500]	training's auc: 0.844308	training's binary_logloss: 0.503487	valid_1's auc: 0.768573	valid_1's binary_logloss: 0.556639
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.844308	training's binary_logloss: 0.503487	valid_1's auc: 0.768573	valid_1's binary_logloss: 0.556639
# |  2        |  0.7686   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.795794	training's binary_logloss: 0.553033	valid_1's auc: 0.768664	valid_1's binary_logloss: 0.566178
# [200]	training's auc: 0.825249	training's binary_logloss: 0.523121	valid_1's auc: 0.769513	valid_1's binary_logloss: 0.557007
# [300]	training's auc: 0.851735	training's binary_logloss: 0.500546	valid_1's auc: 0.768901	valid_1's binary_logloss: 0.556302
# [400]	training's auc: 0.87351	training's binary_logloss: 0.480463	valid_1's auc: 0.7681	valid_1's binary_logloss: 0.556727
# [500]	training's auc: 0.892151	training's binary_logloss: 0.462119	valid_1's auc: 0.767282	valid_1's binary_logloss: 0.557279
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.892151	training's binary_logloss: 0.462119	valid_1's auc: 0.767282	valid_1's binary_logloss: 0.557279
# |  3        |  0.7673   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.769918	training's binary_logloss: 0.568548	valid_1's auc: 0.764727	valid_1's binary_logloss: 0.570756
# [200]	training's auc: 0.784633	training's binary_logloss: 0.550854	valid_1's auc: 0.767443	valid_1's binary_logloss: 0.560271
# [300]	training's auc: 0.796933	training's binary_logloss: 0.540662	valid_1's auc: 0.767809	valid_1's binary_logloss: 0.558557
# [400]	training's auc: 0.807955	training's binary_logloss: 0.531999	valid_1's auc: 0.767727	valid_1's binary_logloss: 0.558119
# [500]	training's auc: 0.817741	training's binary_logloss: 0.524102	valid_1's auc: 0.767019	valid_1's binary_logloss: 0.558239
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.817741	training's binary_logloss: 0.524102	valid_1's auc: 0.767019	valid_1's binary_logloss: 0.558239
# |  4        |  0.767    |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.766538	training's binary_logloss: 0.571737	valid_1's auc: 0.764577	valid_1's binary_logloss: 0.572656
# [200]	training's auc: 0.778595	training's binary_logloss: 0.555062	valid_1's auc: 0.767199	valid_1's binary_logloss: 0.561246
# [300]	training's auc: 0.788694	training's binary_logloss: 0.546404	valid_1's auc: 0.767811	valid_1's binary_logloss: 0.559208
# [400]	training's auc: 0.798004	training's binary_logloss: 0.539175	valid_1's auc: 0.767724	valid_1's binary_logloss: 0.558659
# [500]	training's auc: 0.806146	training's binary_logloss: 0.532648	valid_1's auc: 0.767714	valid_1's binary_logloss: 0.558407
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.806146	training's binary_logloss: 0.532648	valid_1's auc: 0.767714	valid_1's binary_logloss: 0.558407
# |  5        |  0.7677   |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.763066	training's binary_logloss: 0.576702	valid_1's auc: 0.762437	valid_1's binary_logloss: 0.577131
# [200]	training's auc: 0.771348	training's binary_logloss: 0.560307	valid_1's auc: 0.764935	valid_1's binary_logloss: 0.563889
# [300]	training's auc: 0.779092	training's binary_logloss: 0.553253	valid_1's auc: 0.766169	valid_1's binary_logloss: 0.56096
# [400]	training's auc: 0.785154	training's binary_logloss: 0.548288	valid_1's auc: 0.766486	valid_1's binary_logloss: 0.560017
# [500]	training's auc: 0.790259	training's binary_logloss: 0.544186	valid_1's auc: 0.766492	valid_1's binary_logloss: 0.559585
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.790259	training's binary_logloss: 0.544186	valid_1's auc: 0.766492	valid_1's binary_logloss: 0.559585
# |  6        |  0.7665   |  0.6244   |  308.5    |  14.06    |  139.5    |  10.7     |  43.29    |  40.76    |  1.397    |  0.9456   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.765659	training's binary_logloss: 0.574944	valid_1's auc: 0.762583	valid_1's binary_logloss: 0.576555
# [200]	training's auc: 0.774382	training's binary_logloss: 0.558003	valid_1's auc: 0.765118	valid_1's binary_logloss: 0.563433
# [300]	training's auc: 0.782769	training's binary_logloss: 0.550213	valid_1's auc: 0.766268	valid_1's binary_logloss: 0.560441
# [400]	training's auc: 0.789728	training's binary_logloss: 0.544582	valid_1's auc: 0.766396	valid_1's binary_logloss: 0.559694
# [500]	training's auc: 0.795449	training's binary_logloss: 0.539997	valid_1's auc: 0.766419	valid_1's binary_logloss: 0.559365
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.795449	training's binary_logloss: 0.539997	valid_1's auc: 0.766419	valid_1's binary_logloss: 0.559365
# |  7        |  0.7664   |  0.6323   |  429.3    |  11.45    |  45.04    |  4.494    |  57.66    |  42.36    |  0.592    |  0.8029   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.764801	training's binary_logloss: 0.573743	valid_1's auc: 0.763726	valid_1's binary_logloss: 0.57432
# [200]	training's auc: 0.775162	training's binary_logloss: 0.557273	valid_1's auc: 0.766505	valid_1's binary_logloss: 0.561962
# [300]	training's auc: 0.784353	training's binary_logloss: 0.549478	valid_1's auc: 0.767233	valid_1's binary_logloss: 0.559759
# [400]	training's auc: 0.791918	training's binary_logloss: 0.543454	valid_1's auc: 0.767327	valid_1's binary_logloss: 0.559001
# [500]	training's auc: 0.798138	training's binary_logloss: 0.538443	valid_1's auc: 0.767085	valid_1's binary_logloss: 0.558817
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.798138	training's binary_logloss: 0.538443	valid_1's auc: 0.767085	valid_1's binary_logloss: 0.558817
# |  8        |  0.7671   |  0.7427   |  319.5    |  9.93     |  111.8    |  35.35    |  35.0     |  36.71    |  3.602    |  0.9431   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.766437	training's binary_logloss: 0.573543	valid_1's auc: 0.763688	valid_1's binary_logloss: 0.574929
# [200]	training's auc: 0.778519	training's binary_logloss: 0.555167	valid_1's auc: 0.766638	valid_1's binary_logloss: 0.561845
# [300]	training's auc: 0.789929	training's binary_logloss: 0.545688	valid_1's auc: 0.767412	valid_1's binary_logloss: 0.559306
# [400]	training's auc: 0.799432	training's binary_logloss: 0.538231	valid_1's auc: 0.76745	valid_1's binary_logloss: 0.558675
# [500]	training's auc: 0.808493	training's binary_logloss: 0.531036	valid_1's auc: 0.767519	valid_1's binary_logloss: 0.558314
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808493	training's binary_logloss: 0.531036	valid_1's auc: 0.767519	valid_1's binary_logloss: 0.558314
# |  9        |  0.7675   |  0.6409   |  182.8    |  10.41    |  43.94    |  33.35    |  40.72    |  29.16    |  6.572    |  0.7809   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.764715	training's binary_logloss: 0.57377	valid_1's auc: 0.762879	valid_1's binary_logloss: 0.574391
# [200]	training's auc: 0.772899	training's binary_logloss: 0.559192	valid_1's auc: 0.765226	valid_1's binary_logloss: 0.563316
# [300]	training's auc: 0.780313	training's binary_logloss: 0.552366	valid_1's auc: 0.766015	valid_1's binary_logloss: 0.561103
# [400]	training's auc: 0.786885	training's binary_logloss: 0.547095	valid_1's auc: 0.766051	valid_1's binary_logloss: 0.560448
# [500]	training's auc: 0.792094	training's binary_logloss: 0.542887	valid_1's auc: 0.766145	valid_1's binary_logloss: 0.560098
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.792094	training's binary_logloss: 0.542887	valid_1's auc: 0.766145	valid_1's binary_logloss: 0.560098
# |  10       |  0.7661   |  0.9628   |  392.6    |  11.76    |  137.6    |  6.163    |  39.69    |  44.62    |  7.968    |  0.7126   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.788381	training's binary_logloss: 0.558141	valid_1's auc: 0.768113	valid_1's binary_logloss: 0.567818
# [200]	training's auc: 0.813817	training's binary_logloss: 0.53141	valid_1's auc: 0.76971	valid_1's binary_logloss: 0.557398
# [300]	training's auc: 0.835996	training's binary_logloss: 0.512743	valid_1's auc: 0.769263	valid_1's binary_logloss: 0.556315
# [400]	training's auc: 0.854994	training's binary_logloss: 0.496426	valid_1's auc: 0.768536	valid_1's binary_logloss: 0.556446
# Early stopping, best iteration is:
# [175]	training's auc: 0.807821	training's binary_logloss: 0.536573	valid_1's auc: 0.769871	valid_1's binary_logloss: 0.558272
# |  11       |  0.7699   |  0.8032   |  289.9    |  14.1     |  135.2    |  29.54    |  49.69    |  9.132    |  6.842    |  0.9468   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.772086	training's binary_logloss: 0.567344	valid_1's auc: 0.765188	valid_1's binary_logloss: 0.57038
# [200]	training's auc: 0.789985	training's binary_logloss: 0.547264	valid_1's auc: 0.768197	valid_1's binary_logloss: 0.559613
# [300]	training's auc: 0.805588	training's binary_logloss: 0.534634	valid_1's auc: 0.768267	valid_1's binary_logloss: 0.558115
# [400]	training's auc: 0.819212	training's binary_logloss: 0.523556	valid_1's auc: 0.767782	valid_1's binary_logloss: 0.557885
# [500]	training's auc: 0.831029	training's binary_logloss: 0.513754	valid_1's auc: 0.767063	valid_1's binary_logloss: 0.557986
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831029	training's binary_logloss: 0.513754	valid_1's auc: 0.767063	valid_1's binary_logloss: 0.557986
# |  12       |  0.7671   |  0.9302   |  239.3    |  9.413    |  141.8    |  4.039    |  56.17    |  23.41    |  8.839    |  0.9091   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.781875	training's binary_logloss: 0.561507	valid_1's auc: 0.767022	valid_1's binary_logloss: 0.568701
# [200]	training's auc: 0.803884	training's binary_logloss: 0.537629	valid_1's auc: 0.769017	valid_1's binary_logloss: 0.558207
# [300]	training's auc: 0.824188	training's binary_logloss: 0.521002	valid_1's auc: 0.769264	valid_1's binary_logloss: 0.556577
# [400]	training's auc: 0.841963	training's binary_logloss: 0.506316	valid_1's auc: 0.768796	valid_1's binary_logloss: 0.556428
# [500]	training's auc: 0.856605	training's binary_logloss: 0.493244	valid_1's auc: 0.76822	valid_1's binary_logloss: 0.556567
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.856605	training's binary_logloss: 0.493244	valid_1's auc: 0.76822	valid_1's binary_logloss: 0.556567
# |  13       |  0.7682   |  0.8227   |  418.8    |  8.331    |  51.9     |  10.05    |  55.87    |  15.55    |  8.403    |  0.9562   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.787642	training's binary_logloss: 0.556466	valid_1's auc: 0.767255	valid_1's binary_logloss: 0.566516
# [200]	training's auc: 0.813457	training's binary_logloss: 0.530631	valid_1's auc: 0.768878	valid_1's binary_logloss: 0.557487
# [300]	training's auc: 0.835526	training's binary_logloss: 0.512169	valid_1's auc: 0.768358	valid_1's binary_logloss: 0.556852
# [400]	training's auc: 0.854241	training's binary_logloss: 0.495845	valid_1's auc: 0.767762	valid_1's binary_logloss: 0.556979
# [500]	training's auc: 0.870323	training's binary_logloss: 0.481204	valid_1's auc: 0.766861	valid_1's binary_logloss: 0.557549
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.870323	training's binary_logloss: 0.481204	valid_1's auc: 0.766861	valid_1's binary_logloss: 0.557549
# |  14       |  0.7669   |  0.9781   |  232.8    |  10.37    |  170.4    |  30.44    |  45.23    |  8.401    |  0.9375   |  0.8085   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770797	training's binary_logloss: 0.568053	valid_1's auc: 0.765017	valid_1's binary_logloss: 0.570653
# [200]	training's auc: 0.783286	training's binary_logloss: 0.551409	valid_1's auc: 0.767749	valid_1's binary_logloss: 0.560118
# [300]	training's auc: 0.794415	training's binary_logloss: 0.542191	valid_1's auc: 0.768181	valid_1's binary_logloss: 0.558489
# [400]	training's auc: 0.804582	training's binary_logloss: 0.534128	valid_1's auc: 0.767944	valid_1's binary_logloss: 0.558104
# [500]	training's auc: 0.813485	training's binary_logloss: 0.526825	valid_1's auc: 0.767527	valid_1's binary_logloss: 0.557983
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.813485	training's binary_logloss: 0.526825	valid_1's auc: 0.767527	valid_1's binary_logloss: 0.557983
# |  15       |  0.7675   |  0.9303   |  325.1    |  15.91    |  120.2    |  1.1      |  29.0     |  25.81    |  5.161    |  0.5704   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.783569	training's binary_logloss: 0.561753	valid_1's auc: 0.768121	valid_1's binary_logloss: 0.569144
# [200]	training's auc: 0.806894	training's binary_logloss: 0.536217	valid_1's auc: 0.769869	valid_1's binary_logloss: 0.557828
# [300]	training's auc: 0.827228	training's binary_logloss: 0.519354	valid_1's auc: 0.769428	valid_1's binary_logloss: 0.556535
# [400]	training's auc: 0.844947	training's binary_logloss: 0.504415	valid_1's auc: 0.768635	valid_1's binary_logloss: 0.55677
# [500]	training's auc: 0.860213	training's binary_logloss: 0.490969	valid_1's auc: 0.768226	valid_1's binary_logloss: 0.556933
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.860213	training's binary_logloss: 0.490969	valid_1's auc: 0.768226	valid_1's binary_logloss: 0.556933
# |  16       |  0.7682   |  0.7405   |  120.1    |  12.18    |  53.76    |  42.68    |  47.66    |  10.66    |  1.986    |  0.8184   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.764775	training's binary_logloss: 0.578012	valid_1's auc: 0.762147	valid_1's binary_logloss: 0.57942
# [200]	training's auc: 0.776156	training's binary_logloss: 0.557918	valid_1's auc: 0.7658	valid_1's binary_logloss: 0.563757
# [300]	training's auc: 0.786974	training's binary_logloss: 0.548204	valid_1's auc: 0.766908	valid_1's binary_logloss: 0.560319
# [400]	training's auc: 0.795554	training's binary_logloss: 0.541267	valid_1's auc: 0.766992	valid_1's binary_logloss: 0.559367
# [500]	training's auc: 0.803224	training's binary_logloss: 0.535198	valid_1's auc: 0.766845	valid_1's binary_logloss: 0.559102
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.803224	training's binary_logloss: 0.535198	valid_1's auc: 0.766845	valid_1's binary_logloss: 0.559102
# |  17       |  0.7668   |  0.5286   |  456.4    |  13.47    |  96.72    |  41.56    |  61.51    |  29.92    |  3.57     |  0.8466   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.772205	training's binary_logloss: 0.567475	valid_1's auc: 0.765839	valid_1's binary_logloss: 0.570515
# [200]	training's auc: 0.788518	training's binary_logloss: 0.548336	valid_1's auc: 0.768138	valid_1's binary_logloss: 0.559732
# [300]	training's auc: 0.801882	training's binary_logloss: 0.537168	valid_1's auc: 0.768785	valid_1's binary_logloss: 0.557862
# [400]	training's auc: 0.813987	training's binary_logloss: 0.527426	valid_1's auc: 0.768406	valid_1's binary_logloss: 0.557532
# [500]	training's auc: 0.824967	training's binary_logloss: 0.51842	valid_1's auc: 0.768047	valid_1's binary_logloss: 0.557539
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.824967	training's binary_logloss: 0.51842	valid_1's auc: 0.768047	valid_1's binary_logloss: 0.557539
# |  18       |  0.768    |  0.8263   |  179.0    |  11.24    |  25.42    |  22.47    |  41.44    |  25.05    |  2.005    |  0.6375   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.765582	training's binary_logloss: 0.572623	valid_1's auc: 0.762989	valid_1's binary_logloss: 0.57357
# [200]	training's auc: 0.775254	training's binary_logloss: 0.557573	valid_1's auc: 0.765512	valid_1's binary_logloss: 0.562764
# [300]	training's auc: 0.783648	training's binary_logloss: 0.550109	valid_1's auc: 0.76635	valid_1's binary_logloss: 0.560614
# [400]	training's auc: 0.790954	training's binary_logloss: 0.544278	valid_1's auc: 0.766582	valid_1's binary_logloss: 0.559826
# [500]	training's auc: 0.796811	training's binary_logloss: 0.539548	valid_1's auc: 0.76651	valid_1's binary_logloss: 0.559596
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.796811	training's binary_logloss: 0.539548	valid_1's auc: 0.76651	valid_1's binary_logloss: 0.559596
# |  19       |  0.7665   |  0.9644   |  330.1    |  10.67    |  22.2     |  30.45    |  42.41    |  41.12    |  7.102    |  0.755    |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.764517	training's binary_logloss: 0.574043	valid_1's auc: 0.763634	valid_1's binary_logloss: 0.574574
# [200]	training's auc: 0.772735	training's binary_logloss: 0.558399	valid_1's auc: 0.766149	valid_1's binary_logloss: 0.562104
# [300]	training's auc: 0.780703	training's binary_logloss: 0.551374	valid_1's auc: 0.766991	valid_1's binary_logloss: 0.559727
# [400]	training's auc: 0.78774	training's binary_logloss: 0.545884	valid_1's auc: 0.767193	valid_1's binary_logloss: 0.559052
# [500]	training's auc: 0.794396	training's binary_logloss: 0.540719	valid_1's auc: 0.767432	valid_1's binary_logloss: 0.558562
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.794396	training's binary_logloss: 0.540719	valid_1's auc: 0.767432	valid_1's binary_logloss: 0.558562
# |  20       |  0.7674   |  0.6988   |  466.8    |  6.224    |  141.3    |  6.811    |  46.3     |  34.41    |  0.2103   |  0.8806   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.761972	training's binary_logloss: 0.577727	valid_1's auc: 0.762222	valid_1's binary_logloss: 0.577747
# [200]	training's auc: 0.769494	training's binary_logloss: 0.56173	valid_1's auc: 0.764965	valid_1's binary_logloss: 0.564202
# [300]	training's auc: 0.776479	training's binary_logloss: 0.555205	valid_1's auc: 0.765835	valid_1's binary_logloss: 0.561553
# [400]	training's auc: 0.78188	training's binary_logloss: 0.550776	valid_1's auc: 0.765944	valid_1's binary_logloss: 0.56076
# [500]	training's auc: 0.78633	training's binary_logloss: 0.547199	valid_1's auc: 0.765993	valid_1's binary_logloss: 0.560346
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.78633	training's binary_logloss: 0.547199	valid_1's auc: 0.765993	valid_1's binary_logloss: 0.560346
# |  21       |  0.766    |  0.6587   |  250.5    |  9.987    |  100.8    |  48.75    |  36.58    |  41.15    |  9.618    |  0.6229   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.766593	training's binary_logloss: 0.571251	valid_1's auc: 0.763351	valid_1's binary_logloss: 0.572545
# [200]	training's auc: 0.778275	training's binary_logloss: 0.555211	valid_1's auc: 0.766047	valid_1's binary_logloss: 0.561786
# [300]	training's auc: 0.788731	training's binary_logloss: 0.546473	valid_1's auc: 0.766552	valid_1's binary_logloss: 0.559922
# [400]	training's auc: 0.797883	training's binary_logloss: 0.53927	valid_1's auc: 0.76654	valid_1's binary_logloss: 0.559434
# [500]	training's auc: 0.805499	training's binary_logloss: 0.533065	valid_1's auc: 0.766267	valid_1's binary_logloss: 0.559283
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805499	training's binary_logloss: 0.533065	valid_1's auc: 0.766267	valid_1's binary_logloss: 0.559283
# |  22       |  0.7663   |  0.9983   |  254.0    |  15.65    |  172.3    |  4.75     |  36.0     |  34.22    |  8.13     |  0.8197   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.763252	training's binary_logloss: 0.574781	valid_1's auc: 0.762667	valid_1's binary_logloss: 0.574855
# [200]	training's auc: 0.770828	training's binary_logloss: 0.560736	valid_1's auc: 0.765217	valid_1's binary_logloss: 0.563645
# [300]	training's auc: 0.776736	training's binary_logloss: 0.554998	valid_1's auc: 0.765839	valid_1's binary_logloss: 0.561462
# [400]	training's auc: 0.781714	training's binary_logloss: 0.550812	valid_1's auc: 0.766043	valid_1's binary_logloss: 0.560645
# [500]	training's auc: 0.7853	training's binary_logloss: 0.547852	valid_1's auc: 0.766221	valid_1's binary_logloss: 0.560208
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.7853	training's binary_logloss: 0.547852	valid_1's auc: 0.766221	valid_1's binary_logloss: 0.560208
# |  23       |  0.7662   |  0.9707   |  151.7    |  13.38    |  46.18    |  37.89    |  38.31    |  47.9     |  5.181    |  0.5227   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.770019	training's binary_logloss: 0.569028	valid_1's auc: 0.765769	valid_1's binary_logloss: 0.570996
# [200]	training's auc: 0.786419	training's binary_logloss: 0.549686	valid_1's auc: 0.768369	valid_1's binary_logloss: 0.559749
# [300]	training's auc: 0.800249	training's binary_logloss: 0.538467	valid_1's auc: 0.768775	valid_1's binary_logloss: 0.558005
# [400]	training's auc: 0.812427	training's binary_logloss: 0.528699	valid_1's auc: 0.768392	valid_1's binary_logloss: 0.557604
# [500]	training's auc: 0.823336	training's binary_logloss: 0.5198	valid_1's auc: 0.768199	valid_1's binary_logloss: 0.557432
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.823336	training's binary_logloss: 0.5198	valid_1's auc: 0.768199	valid_1's binary_logloss: 0.557432
# |  24       |  0.7682   |  0.8324   |  52.63    |  14.54    |  100.8    |  22.84    |  59.28    |  25.3     |  7.74     |  0.9656   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.765558	training's binary_logloss: 0.57283	valid_1's auc: 0.763838	valid_1's binary_logloss: 0.573588
# [200]	training's auc: 0.776412	training's binary_logloss: 0.556668	valid_1's auc: 0.766333	valid_1's binary_logloss: 0.562069
# [300]	training's auc: 0.78547	training's binary_logloss: 0.548722	valid_1's auc: 0.766993	valid_1's binary_logloss: 0.559886
# [400]	training's auc: 0.7933	training's binary_logloss: 0.542544	valid_1's auc: 0.767132	valid_1's binary_logloss: 0.559223
# [500]	training's auc: 0.800033	training's binary_logloss: 0.537142	valid_1's auc: 0.76686	valid_1's binary_logloss: 0.559105
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.800033	training's binary_logloss: 0.537142	valid_1's auc: 0.76686	valid_1's binary_logloss: 0.559105
# |  25       |  0.7669   |  0.7945   |  227.7    |  10.98    |  10.97    |  29.73    |  58.59    |  36.54    |  5.997    |  0.619    |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.777662	training's binary_logloss: 0.569464	valid_1's auc: 0.76591	valid_1's binary_logloss: 0.575255
# [200]	training's auc: 0.800019	training's binary_logloss: 0.54201	valid_1's auc: 0.769064	valid_1's binary_logloss: 0.560012
# [300]	training's auc: 0.819646	training's binary_logloss: 0.525233	valid_1's auc: 0.769777	valid_1's binary_logloss: 0.556717
# [400]	training's auc: 0.836651	training's binary_logloss: 0.511254	valid_1's auc: 0.769554	valid_1's binary_logloss: 0.556053
# [500]	training's auc: 0.851772	training's binary_logloss: 0.498361	valid_1's auc: 0.769224	valid_1's binary_logloss: 0.556081
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.851772	training's binary_logloss: 0.498361	valid_1's auc: 0.769224	valid_1's binary_logloss: 0.556081
# |  26       |  0.7692   |  0.5221   |  85.95    |  13.05    |  31.7     |  25.54    |  55.78    |  13.9     |  1.522    |  0.9647   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.76288	training's binary_logloss: 0.575232	valid_1's auc: 0.762643	valid_1's binary_logloss: 0.575232
# [200]	training's auc: 0.770019	training's binary_logloss: 0.561333	valid_1's auc: 0.764887	valid_1's binary_logloss: 0.564014
# [300]	training's auc: 0.775516	training's binary_logloss: 0.555651	valid_1's auc: 0.765728	valid_1's binary_logloss: 0.561527
# [400]	training's auc: 0.780716	training's binary_logloss: 0.551452	valid_1's auc: 0.766032	valid_1's binary_logloss: 0.560736
# [500]	training's auc: 0.784209	training's binary_logloss: 0.548606	valid_1's auc: 0.766319	valid_1's binary_logloss: 0.560198
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.784209	training's binary_logloss: 0.548606	valid_1's auc: 0.766319	valid_1's binary_logloss: 0.560198
# |  27       |  0.7663   |  0.8719   |  449.5    |  8.409    |  64.2     |  32.31    |  42.56    |  49.45    |  7.164    |  0.8816   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.768807	training's binary_logloss: 0.569197	valid_1's auc: 0.764736	valid_1's binary_logloss: 0.570977
# [200]	training's auc: 0.78177	training's binary_logloss: 0.55236	valid_1's auc: 0.767444	valid_1's binary_logloss: 0.560385
# [300]	training's auc: 0.792795	training's binary_logloss: 0.543166	valid_1's auc: 0.767733	valid_1's binary_logloss: 0.558726
# [400]	training's auc: 0.803215	training's binary_logloss: 0.535116	valid_1's auc: 0.767836	valid_1's binary_logloss: 0.558147
# [500]	training's auc: 0.812446	training's binary_logloss: 0.527669	valid_1's auc: 0.767193	valid_1's binary_logloss: 0.558154
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.812446	training's binary_logloss: 0.527669	valid_1's auc: 0.767193	valid_1's binary_logloss: 0.558154
# |  28       |  0.7672   |  0.959    |  242.5    |  7.319    |  161.5    |  26.26    |  47.09    |  28.48    |  1.268    |  0.7036   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.786499	training's binary_logloss: 0.564955	valid_1's auc: 0.766305	valid_1's binary_logloss: 0.574827
# [200]	training's auc: 0.813022	training's binary_logloss: 0.533507	valid_1's auc: 0.769435	valid_1's binary_logloss: 0.559358
# [300]	training's auc: 0.835904	training's binary_logloss: 0.513466	valid_1's auc: 0.769765	valid_1's binary_logloss: 0.556423
# [400]	training's auc: 0.855927	training's binary_logloss: 0.496062	valid_1's auc: 0.769108	valid_1's binary_logloss: 0.55618
# [500]	training's auc: 0.872646	training's binary_logloss: 0.480582	valid_1's auc: 0.768544	valid_1's binary_logloss: 0.556502
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.872646	training's binary_logloss: 0.480582	valid_1's auc: 0.768544	valid_1's binary_logloss: 0.556502
# |  29       |  0.7685   |  0.5288   |  298.4    |  14.09    |  182.4    |  37.65    |  54.36    |  7.913    |  3.01     |  0.7732   |
# Training until validation scores don't improve for 300 rounds
# [100]	training's auc: 0.78775	training's binary_logloss: 0.557718	valid_1's auc: 0.768638	valid_1's binary_logloss: 0.566861
# [200]	training's auc: 0.807607	training's binary_logloss: 0.534446	valid_1's auc: 0.769664	valid_1's binary_logloss: 0.557011
# [300]	training's auc: 0.828371	training's binary_logloss: 0.517522	valid_1's auc: 0.769061	valid_1's binary_logloss: 0.556079
# [400]	training's auc: 0.843798	training's binary_logloss: 0.504436	valid_1's auc: 0.768463	valid_1's binary_logloss: 0.556258
# Early stopping, best iteration is:
# [189]	training's auc: 0.805217	training's binary_logloss: 0.536465	valid_1's auc: 0.769838	valid_1's binary_logloss: 0.557295
# |  30       |  0.7698   |  0.7962   |  309.4    |  7.089    |  194.4    |  35.83    |  40.28    |  5.876    |  1.207    |  0.6585   |
# =====================================================================================================================================

# %%
label_en.classes_
# Out:
# array(['Agnostic', 'Atheist', 'Buddhist', 'Christian_Catholic',
#        'Christian_Mormon', 'Christian_Other', 'Christian_Protestant',
#        'Hindu', 'Jewish', 'Muslim', 'Other', 'Sikh'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord_ec = OrdinalEncoder()
ord_ec.fit(train_data[['religion']])
# Out:
# OrdinalEncoder()

# %%
label_en.classes_
# Out:
# array(['Agnostic', 'Atheist', 'Buddhist', 'Christian_Catholic',
#        'Christian_Mormon', 'Christian_Other', 'Christian_Protestant',
#        'Hindu', 'Jewish', 'Muslim', 'Other', 'Sikh'], dtype=object)

# %%
train_data['religion'].value_counts()
# Out:
# Atheist                 10192
# Agnostic                 9624
# Christian_Catholic       6431
# Christian_Other          5137
# Christian_Protestant     4875
# Other                    4770
# Hindu                    1429
# Muslim                   1192
# Buddhist                  850
# Jewish                    487
# Christian_Mormon          428
# Sikh                      117
# Name: religion, dtype: int64

# %%
religion_index = train_data['religion'].value_counts().index.tolist()
religion_index
# Out:
# ['Atheist',
#  'Agnostic',
#  'Christian_Catholic',
#  'Christian_Other',
#  'Christian_Protestant',
#  'Other',
#  'Hindu',
#  'Muslim',
#  'Buddhist',
#  'Jewish',
#  'Christian_Mormon',
#  'Sikh']

# %%
ord_ec.set_params(categories=religion_index)
# Out:
# OrdinalEncoder(categories=['Atheist', 'Agnostic', 'Christian_Catholic',
#                            'Christian_Other', 'Christian_Protestant', 'Other',
#                            'Hindu', 'Muslim', 'Buddhist', 'Jewish',
#                            'Christian_Mormon', 'Sikh'])

# %%
test = ord_ec.fit_transform(train_data[['religion']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-891597e6731c> in <module>
# ----> 1 test = ord_ec.fit_transform(train_data[['religion']])
#
# ~\anaconda3\envs\ml_sol\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\envs\ml_sol\lib\site-packages\sklearn\preprocessing\_encoders.py in fit(self, X, y)
#     680         self
#     681         """
# --> 682         self._fit(X)
#     683
#     684         return self
#
# ~\anaconda3\envs\ml_sol\lib\site-packages\sklearn\preprocessing\_encoders.py in _fit(self, X, handle_unknown)
#      76         if self.categories != 'auto':
#      77             if len(self.categories) != n_features:
# ---> 78                 raise ValueError("Shape mismatch: if categories is an array,"
#      79                                  " it has to be of shape (n_features,).")
#      80
#
# ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).

# %%
ord_ec.categories_
# Out:
# [array(['Agnostic', 'Atheist', 'Buddhist', 'Christian_Catholic',
#         'Christian_Mormon', 'Christian_Other', 'Christian_Protestant',
#         'Hindu', 'Jewish', 'Muslim', 'Other', 'Sikh'], dtype=object)]

# %%
len(religion_index)
# Out:
# 12

# %%
len(train_data['religion'].unique())
# Out:
# 12

# %%
train_data[['religion']]
# Out:
#               religion
# index
# 0                Other
# 1                Hindu
# 2                Other
# 3                Hindu
# 4             Agnostic
# ...                ...
# 45527           Jewish
# 45528          Atheist
# 45529  Christian_Other
# 45530          Atheist
# 45531         Agnostic
#
# [45532 rows x 1 columns]

# %%
|
